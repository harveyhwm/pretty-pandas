# %% [markdown]
# ### **SEXY PANDAS**
# #### An attempt to restyle Pandas Data Frames to reflect Excel-style formatting, and to make re-use of the functions easy
# ----

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### **GLOBAL VARIABLES**

# %%
# set of predefined RGB colors
PALETTES_RGB = {
    'yellow':[252,239,166],
    'green':[122,188,129],
    'red':[231,114,112],
    'white':[255,255,255],
    'blue':[101,147,194],
    'grey':[144,144,148],
    'sns_blue':[13,29,85],
    'sns_yellow':[255,255,221],
    'sns_green':[103,182,193]
}
PALETTES_HEX = {}

# %% [markdown]
# #### **HELPER FUNCTIONS**

# %%
# extract the hex value from a given color and round accordingly, ensuring length==2
def make_hex_color(s, round='nearest'):
    if round=='up':
        s_round = np.ceil(s,0)
    elif round=='down':
        s_round = np.floor(s,0)
    else:
        s_round = np.round(s,0)
    return ('0'+hex(int(s_round))[2:].upper())[-2:]

# %%
# make a full hex color from 3 RGB channels
def rgb_to_hex(channels, round='nearest'):
    return '#'+(''.join([make_hex_color(c, round) for c in channels]))

# %%
# use our helpers to populate hex code dict (we will want to speak generally in hex for this work)
for i in PALETTES_RGB.keys():
    PALETTES_HEX[i] = '#'+(''.join([make_hex_color(color) for color in PALETTES_RGB[i]]))

# %%
# make a range of evenly spaced floats of a given min, max and length
def divide_range(mymin, mymax, size):
    return [mymin+(k*(mymax-mymin)/(size-1)) for k in range(size)]
    # np.arange(mymin,mymax+(1/(size-1)),(1/(size-1))) # alternative way

# %%
def make_quantiles(values, n, mn, mx, spacing='relative'):
    if type(n)==list: n=len(n)
    if spacing == 'even':  # evenly distribute the color palette ignoring the magnitude of the values
        return [np.floor((n-1)*((values<=v).mean()+(values<v).mean())/2) for v in values]
    elif spacing == 'relative':  # factor in the megnitude of the values when making the visuals (default)
        return [np.maximum(0,np.minimum(int((n-1)*(v-mn)/(mx-mn)),n-2)) for v in values] # prevent negative values

# %%
# get RGB colors from hex if we want to go the other way
def get_rgb_colors(c):
    if c in PALETTES_RGB:
        return PALETTES_RGB[c]
    else:
        c = c.replace('#','')
        n = [c[i*int(len(c)/3):(i+1)*int(len(c)/3)] for i in range(3)]
        if len(c)==3: n = [s+s for s in n]
        return [int(n,16) for n in n]

# %%
# generates an RGB color value from a given float, based on its distance from defined min/max values and their associated rgb colors
def generate_color(value, thresholds, colors):
    (min,max) = thresholds
    (min_color,max_color) = colors
    diff = [min_color[i]-max_color[i] for i in range(3)]
    return [min_color[j]-(diff[j]*(value-min)/(max-min)) for j in range(3)]

# %%
def luminosity(v):
    return (0.2126*v[0]+0.7152*v[1]+0.0722*v[2])

# %% [markdown]
# #### **MAIN STYLING FUNCTIONS**

# %%
def apply_colors(col, palette=['yellow', 'green'], default_fill_color='#FFF', default_text_color='#000', type='shade', rows=None, columns=None, mymin=None, mymax=None):
    # by default, use column-wise min and max if nothing is provided
    if mymax is None: mymin, mymax = min(col.values), max(col.values)
    
    # to prevent a divide by zero later on - max must always be greater than min
    if mymax==mymin: mymax=mymin+1
    palette = [get_rgb_colors(p) for p in palette]
    
    if len(palette) == 1:
        # if the palette length is just 1 we just apply it globally - the trivial case
        rgb_vals = [palette[0] for c in col.values]
    else:
        # if the palette length is greater than 1, we assign each value a bespoke color based on its position in the full range
        thresholds = divide_range(mymin, mymax, len(palette))
        quantiles = make_quantiles(col.values, palette, mymin, mymax)
        rgb_vals = [generate_color(c, thresholds[q:q+2], palette[q:q+2]) for c,q in zip(col.values, quantiles)]

    def filter_cells(inputs, default=''):  
        if (columns is not None):
            inputs = [inputs[j] if (mymin <= col.values[j] <= mymax) and (col.name in columns) else default for j in range(len(col.values))]
        if (rows is not None):
            inputs = [inputs[j] if (mymin <= col.values[j] <= mymax) and (j in rows) else default for j in range(len(col.values))]
        return inputs
    
    if type == 'shade':
        res = ['background-color: #'+(''.join([make_hex_color(c) for c in v])) for v in rgb_vals]
        default = 'background-color: '+default_fill_color
        return filter_cells(res, default)
    elif type == 'text_shade':
        tx = ['color: '+('#000' if luminosity(v)>=100 else '#FFF') for v in rgb_vals]
        default = 'color: '+default_text_color
        return filter_cells(tx, default)
    else:
        return ['' for c in col.values]

# %%
def pretty_pandas(df, fill_palette=['yellow','green'], rows=None, columns=None, index='show', group=None, font_size=None, header_size=None,
                  default_fill_color = '#FFF', default_text_color = '#000', bg='white', mymin=None, mymax=None):
    """Generate efficient dataframe styling with fully customizable inputs.

    Keyword arguments:
    todo
    """
    sdf = df.style
    rows_all,columns_all = list(df.index),list(df.columns)
    if mymin is None: mymin=np.min(df.values)
    if mymax is None: mymax=np.max(df.values)

    if index=='hide': sdf.hide_index()
    if header_size is None: header_size=font_size
    if type(fill_palette[0]) != list: fill_palette=[fill_palette] 
    
    for palette in fill_palette:
        row_subset = rows_all if rows is None else [r for r in rows if r in rows_all]
        row_index_subset = [rows_all.index(r) for r in row_subset]
        col_subset = columns_all if columns is None else [c for c in columns if c in columns_all]
        d = df.loc[row_subset,col_subset]
        mymin = max(mymin, np.min(d.values)) if group is None else None
        mymax = min(mymax, np.max(d.values)) if group is None else None
        sdf.apply(apply_colors, palette=palette, default_fill_color=default_fill_color, default_text_color=default_text_color,
                  type='shade', rows=row_index_subset, columns=col_subset, mymin=mymin, mymax=mymax, axis=0)
        sdf.apply(apply_colors, palette=palette, default_fill_color=default_fill_color, default_text_color=default_text_color,
                  type='text_shade', rows=row_index_subset, columns=col_subset, mymin=mymin, mymax=mymax, axis=0)

    return sdf.format('{:.3f}').set_table_styles([{'selector':'tr','props':[('background-color',bg+' !important')]}])

    # sdf.set_properties(**{'font-size': str(font_size)+'pt'})
    # .set_table_styles([{'selector': 'th', 'props': [('font-size', str(22)+'pt !important')]}])

# %% [markdown]
# #### **EXAMPLES**

# %%
alpha = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
test_df = pd.DataFrame([np.arange(26)+(2*np.random.random(26)) for i in range(26)],columns=[a for a in alpha][:26])
# test_df = np.round(test_df,2)

fruits = ['Apple','Watermelon','Orange','Pear','Cherry','Strawberry','Nectarine','Grape','Mango','Blueberry','Pomegranate','Starfruit','Plum','Banana',
          'Raspberry','Mandarin','Jackfruit','Papaya','Kiwi','Pineapple','Lime','Lemon','Apricot','Grapefruit','Melon','Coconut','Avocado','Peach']

test_df.index = fruits[:26]
np.random.shuffle(fruits)

# %%
pretty_pandas(test_df)
# Out:
# <style type="text/css">
# #T_58a49_ tr {
#   background-color: white !important;
# }
# #T_58a49_row0_col0, #T_58a49_row3_col1, #T_58a49_row8_col0, #T_58a49_row18_col1, #T_58a49_row23_col0, #T_58a49_row24_col0, #T_58a49_row24_col1, #T_58a49_row25_col0, #T_58a49_row25_col1 {
#   background-color: #F5ECA4;
#   color: #000;
# }
# #T_58a49_row0_col1, #T_58a49_row8_col2, #T_58a49_row25_col2 {
#   background-color: #F2EBA3;
#   color: #000;
# }
# #T_58a49_row0_col2, #T_58a49_row9_col2, #T_58a49_row11_col3, #T_58a49_row20_col2 {
#   background-color: #EDE9A2;
#   color: #000;
# }
# #T_58a49_row0_col3, #T_58a49_row9_col4, #T_58a49_row15_col3 {
#   background-color: #E9E8A1;
#   color: #000;
# }
# #T_58a49_row0_col4, #T_58a49_row12_col5, #T_58a49_row18_col4, #T_58a49_row22_col5, #T_58a49_row23_col5, #T_58a49_row24_col5 {
#   background-color: #E1E49E;
#   color: #000;
# }
# #T_58a49_row0_col5, #T_58a49_row6_col5, #T_58a49_row8_col6, #T_58a49_row10_col6, #T_58a49_row21_col5 {
#   background-color: #DBE29D;
#   color: #000;
# }
# #T_58a49_row0_col6, #T_58a49_row2_col6, #T_58a49_row3_col7, #T_58a49_row13_col6, #T_58a49_row14_col6, #T_58a49_row25_col6 {
#   background-color: #D8E19C;
#   color: #000;
# }
# #T_58a49_row0_col7, #T_58a49_row3_col6, #T_58a49_row15_col6, #T_58a49_row16_col6, #T_58a49_row25_col7 {
#   background-color: #D7E19C;
#   color: #000;
# }
# #T_58a49_row0_col8, #T_58a49_row1_col7, #T_58a49_row2_col7, #T_58a49_row2_col8, #T_58a49_row10_col8, #T_58a49_row17_col7 {
#   background-color: #D3DF9A;
#   color: #000;
# }
# #T_58a49_row0_col9, #T_58a49_row6_col9, #T_58a49_row12_col9, #T_58a49_row15_col9, #T_58a49_row16_col9, #T_58a49_row20_col9, #T_58a49_row23_col9, #T_58a49_row25_col10 {
#   background-color: #CBDC98;
#   color: #000;
# }
# #T_58a49_row0_col10, #T_58a49_row3_col11, #T_58a49_row10_col10, #T_58a49_row10_col11, #T_58a49_row17_col10, #T_58a49_row23_col10, #T_58a49_row24_col10 {
#   background-color: #C5D996;
#   color: #000;
# }
# #T_58a49_row0_col11, #T_58a49_row4_col10, #T_58a49_row5_col10, #T_58a49_row9_col10, #T_58a49_row11_col10, #T_58a49_row11_col11, #T_58a49_row21_col11, #T_58a49_row25_col11 {
#   background-color: #C7DA97;
#   color: #000;
# }
# #T_58a49_row0_col12, #T_58a49_row0_col13, #T_58a49_row5_col12, #T_58a49_row8_col12, #T_58a49_row11_col12, #T_58a49_row19_col12, #T_58a49_row23_col12, #T_58a49_row24_col12, #T_58a49_row25_col12 {
#   background-color: #BDD694;
#   color: #000;
# }
# #T_58a49_row0_col14, #T_58a49_row12_col15, #T_58a49_row15_col14, #T_58a49_row22_col15, #T_58a49_row24_col15 {
#   background-color: #B2D291;
#   color: #000;
# }
# #T_58a49_row0_col15, #T_58a49_row3_col16, #T_58a49_row5_col16, #T_58a49_row11_col15 {
#   background-color: #AED090;
#   color: #000;
# }
# #T_58a49_row0_col16, #T_58a49_row0_col17, #T_58a49_row6_col16, #T_58a49_row10_col17, #T_58a49_row17_col17, #T_58a49_row18_col16, #T_58a49_row25_col17 {
#   background-color: #A9CE8E;
#   color: #000;
# }
# #T_58a49_row0_col18, #T_58a49_row8_col19, #T_58a49_row14_col19, #T_58a49_row15_col19, #T_58a49_row21_col19 {
#   background-color: #9CC98B;
#   color: #000;
# }
# #T_58a49_row0_col19, #T_58a49_row3_col19, #T_58a49_row10_col18, #T_58a49_row11_col19, #T_58a49_row17_col18, #T_58a49_row19_col18, #T_58a49_row23_col18 {
#   background-color: #9ECA8B;
#   color: #000;
# }
# #T_58a49_row0_col20, #T_58a49_row6_col20, #T_58a49_row18_col20, #T_58a49_row25_col20 {
#   background-color: #95C789;
#   color: #000;
# }
# #T_58a49_row0_col21, #T_58a49_row2_col20, #T_58a49_row3_col21, #T_58a49_row15_col21, #T_58a49_row17_col21, #T_58a49_row21_col20, #T_58a49_row24_col20, #T_58a49_row24_col21 {
#   background-color: #96C789;
#   color: #000;
# }
# #T_58a49_row0_col22, #T_58a49_row13_col22 {
#   background-color: #91C587;
#   color: #000;
# }
# #T_58a49_row0_col23, #T_58a49_row2_col23, #T_58a49_row8_col22, #T_58a49_row10_col23, #T_58a49_row11_col22, #T_58a49_row11_col23, #T_58a49_row18_col22, #T_58a49_row22_col22 {
#   background-color: #8CC386;
#   color: #000;
# }
# #T_58a49_row0_col24 {
#   background-color: #83BF84;
#   color: #000;
# }
# #T_58a49_row0_col25, #T_58a49_row8_col25, #T_58a49_row11_col25, #T_58a49_row16_col25, #T_58a49_row25_col25 {
#   background-color: #7EBE82;
#   color: #000;
# }
# #T_58a49_row1_col0, #T_58a49_row11_col0, #T_58a49_row14_col0 {
#   background-color: #FBEFA6;
#   color: #000;
# }
# #T_58a49_row1_col1, #T_58a49_row2_col0, #T_58a49_row4_col1 {
#   background-color: #F3EBA3;
#   color: #000;
# }
# #T_58a49_row1_col2, #T_58a49_row4_col2, #T_58a49_row5_col3, #T_58a49_row7_col3, #T_58a49_row13_col2, #T_58a49_row20_col3, #T_58a49_row22_col3 {
#   background-color: #EAE8A1;
#   color: #000;
# }
# #T_58a49_row1_col3, #T_58a49_row2_col3, #T_58a49_row4_col3, #T_58a49_row12_col2, #T_58a49_row17_col2, #T_58a49_row17_col3, #T_58a49_row21_col2, #T_58a49_row23_col2, #T_58a49_row24_col2, #T_58a49_row24_col3, #T_58a49_row25_col3 {
#   background-color: #EBE8A1;
#   color: #000;
# }
# #T_58a49_row1_col4, #T_58a49_row11_col5, #T_58a49_row17_col6, #T_58a49_row24_col6 {
#   background-color: #DFE49E;
#   color: #000;
# }
# #T_58a49_row1_col5, #T_58a49_row3_col4, #T_58a49_row3_col5, #T_58a49_row5_col4, #T_58a49_row5_col5, #T_58a49_row17_col5, #T_58a49_row20_col4 {
#   background-color: #E2E59F;
#   color: #000;
# }
# #T_58a49_row1_col6 {
#   background-color: #DEE39E;
#   color: #000;
# }
# #T_58a49_row1_col8 {
#   background-color: #CDDC98;
#   color: #000;
# }
# #T_58a49_row1_col9, #T_58a49_row9_col7, #T_58a49_row11_col8, #T_58a49_row14_col8 {
#   background-color: #D1DE9A;
#   color: #000;
# }
# #T_58a49_row1_col10, #T_58a49_row2_col9, #T_58a49_row10_col9 {
#   background-color: #CADB98;
#   color: #000;
# }
# #T_58a49_row1_col11, #T_58a49_row22_col12 {
#   background-color: #C0D895;
#   color: #000;
# }
# #T_58a49_row1_col12, #T_58a49_row6_col13, #T_58a49_row6_col14, #T_58a49_row9_col13, #T_58a49_row17_col13, #T_58a49_row20_col14, #T_58a49_row21_col14 {
#   background-color: #B9D593;
#   color: #000;
# }
# #T_58a49_row1_col13, #T_58a49_row7_col12, #T_58a49_row20_col12, #T_58a49_row24_col13 {
#   background-color: #BCD694;
#   color: #000;
# }
# #T_58a49_row1_col14, #T_58a49_row7_col15, #T_58a49_row17_col15, #T_58a49_row20_col15, #T_58a49_row22_col14 {
#   background-color: #AFD190;
#   color: #000;
# }
# #T_58a49_row1_col15, #T_58a49_row14_col14, #T_58a49_row16_col15, #T_58a49_row19_col14 {
#   background-color: #B3D291;
#   color: #000;
# }
# #T_58a49_row1_col16, #T_58a49_row5_col18, #T_58a49_row9_col16, #T_58a49_row18_col18, #T_58a49_row20_col17, #T_58a49_row20_col18, #T_58a49_row22_col16, #T_58a49_row22_col17, #T_58a49_row23_col16, #T_58a49_row23_col17, #T_58a49_row24_col17 {
#   background-color: #A5CD8D;
#   color: #000;
# }
# #T_58a49_row1_col17, #T_58a49_row2_col16, #T_58a49_row19_col16, #T_58a49_row20_col16 {
#   background-color: #A6CD8E;
#   color: #000;
# }
# #T_58a49_row1_col18, #T_58a49_row2_col18, #T_58a49_row8_col17, #T_58a49_row8_col18, #T_58a49_row13_col17, #T_58a49_row16_col17 {
#   background-color: #A3CC8D;
#   color: #000;
# }
# #T_58a49_row1_col19, #T_58a49_row24_col19 {
#   background-color: #9AC98A;
#   color: #000;
# }
# #T_58a49_row1_col20, #T_58a49_row4_col20, #T_58a49_row10_col21, #T_58a49_row16_col20, #T_58a49_row19_col20 {
#   background-color: #94C688;
#   color: #000;
# }
# #T_58a49_row1_col21, #T_58a49_row4_col22, #T_58a49_row5_col21, #T_58a49_row9_col22, #T_58a49_row19_col22, #T_58a49_row21_col21, #T_58a49_row22_col21, #T_58a49_row23_col21 {
#   background-color: #8FC487;
#   color: #000;
# }
# #T_58a49_row1_col22, #T_58a49_row21_col23 {
#   background-color: #8AC285;
#   color: #000;
# }
# #T_58a49_row1_col23, #T_58a49_row2_col24, #T_58a49_row3_col24, #T_58a49_row4_col24, #T_58a49_row6_col23, #T_58a49_row11_col24, #T_58a49_row17_col23, #T_58a49_row22_col23 {
#   background-color: #84C084;
#   color: #000;
# }
# #T_58a49_row1_col24, #T_58a49_row3_col25, #T_58a49_row4_col25, #T_58a49_row6_col24, #T_58a49_row6_col25, #T_58a49_row7_col24, #T_58a49_row7_col25, #T_58a49_row14_col24, #T_58a49_row14_col25, #T_58a49_row16_col24 {
#   background-color: #81BF83;
#   color: #000;
# }
# #T_58a49_row1_col25 {
#   background-color: #7EBD82;
#   color: #000;
# }
# #T_58a49_row2_col1, #T_58a49_row6_col1, #T_58a49_row12_col1, #T_58a49_row13_col1, #T_58a49_row16_col0 {
#   background-color: #F4ECA4;
#   color: #000;
# }
# #T_58a49_

# %%
pretty_pandas(
    test_df, index='show', font_size=11, header_size=12,
    # fill_palette=['#FFFFDD','#DAECB8','#87C6BD','#4B96BE','#2E4C9B','#0D1D55'],
    fill_palette=['#e8f6b1', '#b2e1b6', '#65c3bf', '#2ca1c2', '#216daf', '#253997'],
    rows = list(test_df.index)[8:18], #['Starfruit','Plum','Banana','Raspberry'],
    columns = ['B','C','D','E','F','G','H','I'],
    default_fill_color = '#F9F9F9',
    default_text_color = '#DDDDE4',
)
# Out:
# <style type="text/css">
# #T_a1a49_ tr {
#   background-color: white !important;
# }
# #T_a1a49_row0_col0, #T_a1a49_row0_col1, #T_a1a49_row0_col2, #T_a1a49_row0_col3, #T_a1a49_row0_col4, #T_a1a49_row0_col5, #T_a1a49_row0_col6, #T_a1a49_row0_col7, #T_a1a49_row0_col8, #T_a1a49_row0_col9, #T_a1a49_row0_col10, #T_a1a49_row0_col11, #T_a1a49_row0_col12, #T_a1a49_row0_col13, #T_a1a49_row0_col14, #T_a1a49_row0_col15, #T_a1a49_row0_col16, #T_a1a49_row0_col17, #T_a1a49_row0_col18, #T_a1a49_row0_col19, #T_a1a49_row0_col20, #T_a1a49_row0_col21, #T_a1a49_row0_col22, #T_a1a49_row0_col23, #T_a1a49_row0_col24, #T_a1a49_row0_col25, #T_a1a49_row1_col0, #T_a1a49_row1_col1, #T_a1a49_row1_col2, #T_a1a49_row1_col3, #T_a1a49_row1_col4, #T_a1a49_row1_col5, #T_a1a49_row1_col6, #T_a1a49_row1_col7, #T_a1a49_row1_col8, #T_a1a49_row1_col9, #T_a1a49_row1_col10, #T_a1a49_row1_col11, #T_a1a49_row1_col12, #T_a1a49_row1_col13, #T_a1a49_row1_col14, #T_a1a49_row1_col15, #T_a1a49_row1_col16, #T_a1a49_row1_col17, #T_a1a49_row1_col18, #T_a1a49_row1_col19, #T_a1a49_row1_col20, #T_a1a49_row1_col21, #T_a1a49_row1_col22, #T_a1a49_row1_col23, #T_a1a49_row1_col24, #T_a1a49_row1_col25, #T_a1a49_row2_col0, #T_a1a49_row2_col1, #T_a1a49_row2_col2, #T_a1a49_row2_col3, #T_a1a49_row2_col4, #T_a1a49_row2_col5, #T_a1a49_row2_col6, #T_a1a49_row2_col7, #T_a1a49_row2_col8, #T_a1a49_row2_col9, #T_a1a49_row2_col10, #T_a1a49_row2_col11, #T_a1a49_row2_col12, #T_a1a49_row2_col13, #T_a1a49_row2_col14, #T_a1a49_row2_col15, #T_a1a49_row2_col16, #T_a1a49_row2_col17, #T_a1a49_row2_col18, #T_a1a49_row2_col19, #T_a1a49_row2_col20, #T_a1a49_row2_col21, #T_a1a49_row2_col22, #T_a1a49_row2_col23, #T_a1a49_row2_col24, #T_a1a49_row2_col25, #T_a1a49_row3_col0, #T_a1a49_row3_col1, #T_a1a49_row3_col2, #T_a1a49_row3_col3, #T_a1a49_row3_col4, #T_a1a49_row3_col5, #T_a1a49_row3_col6, #T_a1a49_row3_col7, #T_a1a49_row3_col8, #T_a1a49_row3_col9, #T_a1a49_row3_col10, #T_a1a49_row3_col11, #T_a1a49_row3_col12, #T_a1a49_row3_col13, #T_a1a49_row3_col14, #T_a1a49_row3_col15, #T_a1a49_row3_col16, #T_a1a49_row3_col17, #T_a1a49_row3_col18, #T_a1a49_row3_col19, #T_a1a49_row3_col20, #T_a1a49_row3_col21, #T_a1a49_row3_col22, #T_a1a49_row3_col23, #T_a1a49_row3_col24, #T_a1a49_row3_col25, #T_a1a49_row4_col0, #T_a1a49_row4_col1, #T_a1a49_row4_col2, #T_a1a49_row4_col3, #T_a1a49_row4_col4, #T_a1a49_row4_col5, #T_a1a49_row4_col6, #T_a1a49_row4_col7, #T_a1a49_row4_col8, #T_a1a49_row4_col9, #T_a1a49_row4_col10, #T_a1a49_row4_col11, #T_a1a49_row4_col12, #T_a1a49_row4_col13, #T_a1a49_row4_col14, #T_a1a49_row4_col15, #T_a1a49_row4_col16, #T_a1a49_row4_col17, #T_a1a49_row4_col18, #T_a1a49_row4_col19, #T_a1a49_row4_col20, #T_a1a49_row4_col21, #T_a1a49_row4_col22, #T_a1a49_row4_col23, #T_a1a49_row4_col24, #T_a1a49_row4_col25, #T_a1a49_row5_col0, #T_a1a49_row5_col1, #T_a1a49_row5_col2, #T_a1a49_row5_col3, #T_a1a49_row5_col4, #T_a1a49_row5_col5, #T_a1a49_row5_col6, #T_a1a49_row5_col7, #T_a1a49_row5_col8, #T_a1a49_row5_col9, #T_a1a49_row5_col10, #T_a1a49_row5_col11, #T_a1a49_row5_col12, #T_a1a49_row5_col13, #T_a1a49_row5_col14, #T_a1a49_row5_col15, #T_a1a49_row5_col16, #T_a1a49_row5_col17, #T_a1a49_row5_col18, #T_a1a49_row5_col19, #T_a1a49_row5_col20, #T_a1a49_row5_col21, #T_a1a49_row5_col22, #T_a1a49_row5_col23, #T_a1a49_row5_col24, #T_a1a49_row5_col25, #T_a1a49_row6_col0, #T_a1a49_row6_col1, #T_a1a49_row6_col2, #T_a1a49_row6_col3, #T_a1a49_row6_col4, #T_a1a49_row6_col5, #T_a1a49_row6_col6, #T_a1a49_row6_col7, #T_a1a49_row6_col8, #T_a1a49_row6_col9, #T_a1a49_row6_col10, #T_a1a49_row6_col11, #T_a1a49_row6_col12, #T_a1a49_row6_col13, #T_a1a49_row6_col14, #T_a1a49_row6_col15, #T_a1a49_row6_col16, #T_a1a49_row6_col17, #T_a1a49_row6_col18, #T_a1a49_row6_col19, #T_a1a49_row6_col20, #T_a1a49_row6_col21, #T_a1a49_row6_col22, #T_a1a49_row6_col23, #T_a1a49_row6_col24, #T_a1a49_row6_col25, #T_a1a49_row7_col0, #T_a1a49_row7_col1, #T_a1a49_row7_col2, #T_a1a49_row7_col3, #T_a1a49_row7_col4, #T_a1a49_row7_col5, #T_a1a49_row7_col6, #T_a1a49_row7_col7, #T_a1a49_row7_col8, #T_a1a49_row7_col9, #T_a1a49_row7_col10, #T_a1a49_row7_col11, #T_a1a ...

# %%
pretty_pandas(
    test_df, index='show', font_size=11, header_size=12, mymin=4, mymax=18,
    fill_palette=list(sns.color_palette('YlOrRd').as_hex()),
    default_fill_color = '#F9F9F9',
    default_text_color = '#555',
)
# Out:
# <style type="text/css">
# #T_9e748_ tr {
#   background-color: white !important;
# }
# #T_9e748_row0_col0, #T_9e748_row0_col1, #T_9e748_row0_col2, #T_9e748_row0_col3, #T_9e748_row0_col18, #T_9e748_row0_col19, #T_9e748_row0_col20, #T_9e748_row0_col21, #T_9e748_row0_col22, #T_9e748_row0_col23, #T_9e748_row0_col24, #T_9e748_row0_col25, #T_9e748_row1_col0, #T_9e748_row1_col1, #T_9e748_row1_col2, #T_9e748_row1_col3, #T_9e748_row1_col18, #T_9e748_row1_col19, #T_9e748_row1_col20, #T_9e748_row1_col21, #T_9e748_row1_col22, #T_9e748_row1_col23, #T_9e748_row1_col24, #T_9e748_row1_col25, #T_9e748_row2_col0, #T_9e748_row2_col1, #T_9e748_row2_col2, #T_9e748_row2_col3, #T_9e748_row2_col17, #T_9e748_row2_col18, #T_9e748_row2_col19, #T_9e748_row2_col20, #T_9e748_row2_col21, #T_9e748_row2_col22, #T_9e748_row2_col23, #T_9e748_row2_col24, #T_9e748_row2_col25, #T_9e748_row3_col0, #T_9e748_row3_col1, #T_9e748_row3_col2, #T_9e748_row3_col3, #T_9e748_row3_col17, #T_9e748_row3_col18, #T_9e748_row3_col19, #T_9e748_row3_col20, #T_9e748_row3_col21, #T_9e748_row3_col22, #T_9e748_row3_col23, #T_9e748_row3_col24, #T_9e748_row3_col25, #T_9e748_row4_col0, #T_9e748_row4_col1, #T_9e748_row4_col2, #T_9e748_row4_col3, #T_9e748_row4_col17, #T_9e748_row4_col18, #T_9e748_row4_col19, #T_9e748_row4_col20, #T_9e748_row4_col21, #T_9e748_row4_col22, #T_9e748_row4_col23, #T_9e748_row4_col24, #T_9e748_row4_col25, #T_9e748_row5_col0, #T_9e748_row5_col1, #T_9e748_row5_col2, #T_9e748_row5_col3, #T_9e748_row5_col18, #T_9e748_row5_col19, #T_9e748_row5_col20, #T_9e748_row5_col21, #T_9e748_row5_col22, #T_9e748_row5_col23, #T_9e748_row5_col24, #T_9e748_row5_col25, #T_9e748_row6_col0, #T_9e748_row6_col1, #T_9e748_row6_col2, #T_9e748_row6_col17, #T_9e748_row6_col18, #T_9e748_row6_col19, #T_9e748_row6_col20, #T_9e748_row6_col21, #T_9e748_row6_col22, #T_9e748_row6_col23, #T_9e748_row6_col24, #T_9e748_row6_col25, #T_9e748_row7_col0, #T_9e748_row7_col1, #T_9e748_row7_col2, #T_9e748_row7_col3, #T_9e748_row7_col17, #T_9e748_row7_col18, #T_9e748_row7_col19, #T_9e748_row7_col20, #T_9e748_row7_col21, #T_9e748_row7_col22, #T_9e748_row7_col23, #T_9e748_row7_col24, #T_9e748_row7_col25, #T_9e748_row8_col0, #T_9e748_row8_col1, #T_9e748_row8_col2, #T_9e748_row8_col17, #T_9e748_row8_col18, #T_9e748_row8_col19, #T_9e748_row8_col20, #T_9e748_row8_col21, #T_9e748_row8_col22, #T_9e748_row8_col23, #T_9e748_row8_col24, #T_9e748_row8_col25, #T_9e748_row9_col0, #T_9e748_row9_col1, #T_9e748_row9_col2, #T_9e748_row9_col3, #T_9e748_row9_col17, #T_9e748_row9_col18, #T_9e748_row9_col19, #T_9e748_row9_col20, #T_9e748_row9_col21, #T_9e748_row9_col22, #T_9e748_row9_col23, #T_9e748_row9_col24, #T_9e748_row9_col25, #T_9e748_row10_col0, #T_9e748_row10_col1, #T_9e748_row10_col2, #T_9e748_row10_col18, #T_9e748_row10_col19, #T_9e748_row10_col20, #T_9e748_row10_col21, #T_9e748_row10_col22, #T_9e748_row10_col23, #T_9e748_row10_col24, #T_9e748_row10_col25, #T_9e748_row11_col0, #T_9e748_row11_col1, #T_9e748_row11_col2, #T_9e748_row11_col3, #T_9e748_row11_col17, #T_9e748_row11_col18, #T_9e748_row11_col19, #T_9e748_row11_col20, #T_9e748_row11_col21, #T_9e748_row11_col22, #T_9e748_row11_col23, #T_9e748_row11_col24, #T_9e748_row11_col25, #T_9e748_row12_col0, #T_9e748_row12_col1, #T_9e748_row12_col2, #T_9e748_row12_col17, #T_9e748_row12_col18, #T_9e748_row12_col19, #T_9e748_row12_col20, #T_9e748_row12_col21, #T_9e748_row12_col22, #T_9e748_row12_col23, #T_9e748_row12_col24, #T_9e748_row12_col25, #T_9e748_row13_col0, #T_9e748_row13_col1, #T_9e748_row13_col2, #T_9e748_row13_col3, #T_9e748_row13_col17, #T_9e748_row13_col18, #T_9e748_row13_col19, #T_9e748_row13_col20, #T_9e748_row13_col21, #T_9e748_row13_col22, #T_9e748_row13_col23, #T_9e748_row13_col24, #T_9e748_row13_col25, #T_9e748_row14_col0, #T_9e748_row14_col1, #T_9e748_row14_col2, #T_9e748_row14_col17, #T_9e748_row14_col18, #T_9e748_row14_col19, #T_9e748_row14_col20, #T_9e748_row14_col21, #T_9e748_row14_col22, #T_9e748_row14_col23, #T_9e748_row14_col24, #T_9e748_row14_col25, #T_9e748_row15_col0, #T_9e748_row15_col1, #T_9e748_row15_col2, #T_9e748_row15_col18, #T_ ...
#   background-color: #F9F9F9;
#   color: #555;
# }
# #T_9e748_row0_col4, #T_9e748_row24_col5 {
#   background-color: #FED97E;
#   color: #000;
# }
# #T_9e748_row0_col5, #T_9e748_row6_col5 {
#   background-color: #FECD69;
#   color: #000;
# }
# #T_9e748_row0_col6, #T_9e748_row3_col7, #T_9e748_row14_col6, #T_9e748_row25_col6 {
#   background-color: #FEC260;
#   color: #000;
# }
# #T_9e748_row0_col7, #T_9e748_row16_col6 {
#   background-color: #FEC05F;
#   color: #000;
# }
# #T_9e748_row0_col8, #T_9e748_row10_col8 {
#   background-color: #FEB353;
#   color: #000;
# }
# #T_9e748_row0_col9, #T_9e748_row6_col9 {
#   background-color: #FE9541;
#   color: #000;
# }
# #T_9e748_row0_col10, #T_9e748_row10_col10, #T_9e748_row24_col10 {
#   background-color: #FD7C38;
#   color: #000;
# }
# #T_9e748_row0_col11, #T_9e748_row4_col10 {
#   background-color: #FD843B;
#   color: #000;
# }
# #T_9e748_row0_col12 {
#   background-color: #F8582E;
#   color: #000;
# }
# #T_9e748_row0_col13, #T_9e748_row5_col12, #T_9e748_row8_col12, #T_9e748_row24_col12 {
#   background-color: #F85A2E;
#   color: #000;
# }
# #T_9e748_row0_col14 {
#   background-color: #E62620;
#   color: #FFF;
# }
# #T_9e748_row0_col1

# %%
#.hide_index()

#cols=[[['sns_yellow','sns_green','sns_blue'],'shade']],
#[['sns_blue','sns_green'],'shade',['A','C']]]

#).format('{:.3f}').hide_index()

#.highlight_max(color='lightgreen')
#.bar(subset='C',color='#AAC')
