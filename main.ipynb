# %% [markdown]
# ### **SEXY PANDAS**
# #### An attempt to restyle Pandas Data Frames to reflect Excel-style formatting, and to make re-use of the functions easy
# ----

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json

# %%
import dataframe_image # use this package to help print out our new styles

# %% [markdown]
# #### **GLOBAL VARIABLES**

# %%
# set of predefined RGB colors
PALETTES_RGB = {
    'yellow':[252,239,166],
    'green':[122,188,129],
    'red':[231,114,112],
    'white':[255,255,255],
    'blue':[101,147,194],
    'grey':[144,144,148],
    'sns_blue':[13,29,85],
    'sns_yellow':[255,255,221],
    'sns_green':[103,182,193]
}
PALETTES_HEX = {}

# %% [markdown]
# #### **HELPER FUNCTIONS**

# %%
# self-ingestion to get out our python code when regular export fails
def get_raw_python_from_notebook(notebook,python=None):
    if python is None: python=notebook
    with open(notebook+'.ipynb','r') as f:
        rawpy = json.load(f)
    rawpy = [[] if c['source'] == [] else c['source'] for c in rawpy['cells'] if c['cell_type']=='code']
    for r in rawpy:
        r.extend(['\n','\n'])
    raw = [l for r in rawpy for l in r]
    with open(python+'.py', 'w') as f:
        f.write(''.join(raw))

# %%
get_raw_python_from_notebook('main')

# %%
# extract the hex value from a given color and round accordingly, ensuring length==2
def make_hex_color(s, round='nearest'):
    if round=='up':
        s_round = np.ceil(s,0)
    elif round=='down':
        s_round = np.floor(s,0)
    else:
        s_round = np.round(s,0)
    return ('0'+hex(int(s_round))[2:].upper())[-2:]

# %%
# make a full hex color from 3 RGB channels
def rgb_to_hex(channels, round='nearest'):
    return '#'+(''.join([make_hex_color(c, round) for c in channels]))

# %%
# use our helpers to populate hex code dict (we will want to speak generally in hex for this work)
for i in PALETTES_RGB.keys():
    PALETTES_HEX[i] = '#'+(''.join([make_hex_color(color) for color in PALETTES_RGB[i]]))

# %%
# make a range of evenly spaced floats of a given min, max and length
def divide_range(mymin, mymax, size, thresholds):
    return [mymin+(k*(mymax-mymin)/(size-1)) for k in range(size)]
    # np.arange(mymin,mymax+(1/(size-1)),(1/(size-1))) # alternative way

# %%
def make_quantiles(values, n, mn, mx, spacing='relative'):
    if type(n)==list: n=len(n)
    if spacing == 'even':  # evenly distribute the color palette ignoring the magnitude of the values
        return [np.floor((n-1)*((values<=v).mean()+(values<v).mean())/2) for v in values]
    elif spacing == 'relative':  # factor in the megnitude of the values when making the visuals (default)
        return [np.maximum(0,np.minimum(int((n-1)*(v-mn)/(mx-mn)),n-2)) for v in values] # prevent negative values

# %%
# get RGB colors from hex if we want to go the other way
def get_rgb_colors(c):
    if c in PALETTES_RGB:
        return PALETTES_RGB[c]
    else:
        c = c.replace('#','')
        n = [c[i*int(len(c)/3):(i+1)*int(len(c)/3)] for i in range(3)]
        if len(c)==3: n = [s+s for s in n]
        return [int(n,16) for n in n]

# %%
# generates an RGB color value from a given float, based on its distance from defined min/max values and their associated rgb colors
def generate_color(value, thresholds, colors):
    (min,max) = thresholds
    (min_color,max_color) = colors
    diff = [min_color[i]-max_color[i] for i in range(3)]
    return [min_color[j]-(diff[j]*(value-min)/(max-min)) for j in range(3)]

# %%
def luminosity(v):
    return (0.2126*v[0]+0.7152*v[1]+0.0722*v[2])

# %%
def type_format(data,val,number):
    if number in [None,'abs']:
        return max(np.min(data),min(np.max(data),val))
    elif number=='pct':
        return np.quantile(data,val/100)

# %% [markdown]
# #### **MAIN STYLING FUNCTIONS**

# %%
def apply_colors(col, palette=['yellow', 'green'], default_fill_color='#FFF', default_text_color='#000', type='shade', rows=None, columns=None, mymin=None, mymax=None):
    # by default, use column-wise min and max if nothing is provided
    if mymax is None: mymin, mymax = min(col.values), max(col.values)
    
    # to prevent a divide by zero later on - max must always be greater than min
    if mymax==mymin: mymax=mymin+1
    palette = [get_rgb_colors(p) for p in palette]
    
    if len(palette) == 1:
        # if the palette length is just 1 we just apply it globally - the trivial case
        rgb_vals = [palette[0] for c in col.values]
    else:
        # if the palette length is greater than 1, we assign each value a bespoke color based on its position in the full range
        thresholds = divide_range(mymin, mymax, len(palette))
        quantiles = make_quantiles(col.values, palette, mymin, mymax)
        rgb_vals = [generate_color(c, thresholds[q:q+2], palette[q:q+2]) for c,q in zip(col.values, quantiles)]

    def filter_cells(inputs, default=''):  
        if (columns is not None):
            inputs = [inputs[j] if (mymin <= col.values[j] <= mymax) and (col.name in columns) else default for j in range(len(col.values))]
        if (rows is not None):
            inputs = [inputs[j] if (mymin <= col.values[j] <= mymax) and (j in rows) else default for j in range(len(col.values))]
        return inputs
    
    if type == 'shade':
        res = ['background-color: #'+(''.join([make_hex_color(c) for c in v])) for v in rgb_vals]
        default = 'background-color: '+default_fill_color
        return filter_cells(res, default)
    elif type == 'text_shade':
        tx = ['color: '+('#000' if luminosity(v)>=100 else '#FFF') for v in rgb_vals]
        default = 'color: '+default_text_color
        return filter_cells(tx, default)
    else:
        return ['' for c in col.values]

# %% [markdown]
# #####
# The **pretty_pandas** function acts as the main entry point to the styling, and can work with text and fill colors and other formatting:

# %%
def pretty_pandas(df, fill_palette=['yellow','green'], rows=None, columns=None, index='show', group=None, font_size=None, header_size=None,
                  default_fill_color='#FFF', default_text_color='#000', bg='white', mymin=None, mymax=None):
    """Generate efficient dataframe styling with fully customizable inputs.

    Keyword arguments:
    todo
    """
    sdf = df.style
    rows_all,columns_all = list(df.index),list(df.columns)
    if mymin is None: mymin=np.min(df.values)
    if mymax is None: mymax=np.max(df.values)

    if index=='hide': sdf.hide_index()
    if header_size is None: header_size=font_size
    if type(fill_palette[0]) != list: fill_palette=[fill_palette] 
    
    for palette in fill_palette:
        row_subset = rows_all if rows is None else [r for r in rows if r in rows_all]
        row_index_subset = [rows_all.index(r) for r in row_subset]
        col_subset = columns_all if columns is None else [c for c in columns if c in columns_all]
        d = df.loc[row_subset,col_subset]
        mymin = max(mymin, np.min(d.values)) if group is None else None
        mymax = min(mymax, np.max(d.values)) if group is None else None
        sdf.apply(apply_colors, palette=palette, default_fill_color=default_fill_color, default_text_color=default_text_color,
                  type='shade', rows=row_index_subset, columns=col_subset, mymin=mymin, mymax=mymax, axis=0)
        sdf.apply(apply_colors, palette=palette, default_fill_color=default_fill_color, default_text_color=default_text_color,
                  type='text_shade', rows=row_index_subset, columns=col_subset, mymin=mymin, mymax=mymax, axis=0)

    return sdf.format('{:.3f}').set_table_styles([{'selector':'tr','props':[('background-color',bg+' !important')]}])

    # sdf.set_properties(**{'font-size': str(font_size)+'pt'})
    # .set_table_styles([{'selector': 'th', 'props': [('font-size', str(22)+'pt !important')]}])

# %% [markdown]
# #### **EXAMPLES**

# %%
alpha = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
test_df = pd.DataFrame([np.arange(26)+(2*np.random.random(26)) for i in range(26)],columns=[a for a in alpha][:26])
# test_df = np.round(test_df,2)

fruits = ['Apple','Watermelon','Orange','Pear','Cherry','Strawberry','Nectarine','Grape','Mango','Blueberry','Pomegranate','Starfruit','Plum','Banana',
          'Raspberry','Mandarin','Jackfruit','Papaya','Kiwi','Pineapple','Lime','Lemon','Apricot','Grapefruit','Melon','Coconut','Avocado','Peach']

test_df.index = fruits[:26]
np.random.shuffle(fruits)

# %%
pretty_pandas(test_df)
# Out:
# <style type="text/css">
# #T_53b03_ tr {
#   background-color: white !important;
# }
# #T_53b03_row0_col0, #T_53b03_row2_col0, #T_53b03_row8_col0, #T_53b03_row11_col0, #T_53b03_row15_col0, #T_53b03_row16_col0, #T_53b03_row20_col1, #T_53b03_row22_col1 {
#   background-color: #F6EDA4;
#   color: #000;
# }
# #T_53b03_row0_col1, #T_53b03_row11_col1, #T_53b03_row23_col0, #T_53b03_row24_col0 {
#   background-color: #F4ECA4;
#   color: #000;
# }
# #T_53b03_row0_col2, #T_53b03_row0_col3, #T_53b03_row1_col2, #T_53b03_row4_col3, #T_53b03_row13_col2, #T_53b03_row14_col3, #T_53b03_row17_col3, #T_53b03_row24_col2 {
#   background-color: #EAE8A1;
#   color: #000;
# }
# #T_53b03_row0_col4, #T_53b03_row14_col4, #T_53b03_row17_col5, #T_53b03_row23_col4 {
#   background-color: #E3E59F;
#   color: #000;
# }
# #T_53b03_row0_col5, #T_53b03_row3_col4, #T_53b03_row16_col5, #T_53b03_row20_col5 {
#   background-color: #E0E49E;
#   color: #000;
# }
# #T_53b03_row0_col6, #T_53b03_row5_col7, #T_53b03_row24_col6 {
#   background-color: #DAE29C;
#   color: #000;
# }
# #T_53b03_row0_col7, #T_53b03_row18_col8, #T_53b03_row24_col7 {
#   background-color: #D2DE9A;
#   color: #000;
# }
# #T_53b03_row0_col8, #T_53b03_row2_col9, #T_53b03_row6_col9, #T_53b03_row8_col8, #T_53b03_row14_col8, #T_53b03_row20_col9, #T_53b03_row21_col8, #T_53b03_row22_col9 {
#   background-color: #CFDD99;
#   color: #000;
# }
# #T_53b03_row0_col9, #T_53b03_row7_col9, #T_53b03_row10_col10, #T_53b03_row18_col9 {
#   background-color: #C8DB97;
#   color: #000;
# }
# #T_53b03_row0_col10, #T_53b03_row4_col10, #T_53b03_row8_col11, #T_53b03_row15_col11, #T_53b03_row20_col11, #T_53b03_row25_col10, #T_53b03_row25_col11 {
#   background-color: #C3D996;
#   color: #000;
# }
# #T_53b03_row0_col11, #T_53b03_row9_col11, #T_53b03_row12_col12, #T_53b03_row22_col11 {
#   background-color: #BFD795;
#   color: #000;
# }
# #T_53b03_row0_col12 {
#   background-color: #C0D895;
#   color: #000;
# }
# #T_53b03_row0_col13, #T_53b03_row7_col12 {
#   background-color: #BBD694;
#   color: #000;
# }
# #T_53b03_row0_col14, #T_53b03_row2_col13, #T_53b03_row9_col14, #T_53b03_row23_col13, #T_53b03_row24_col13, #T_53b03_row25_col14 {
#   background-color: #B7D492;
#   color: #000;
# }
# #T_53b03_row0_col15, #T_53b03_row3_col15, #T_53b03_row10_col14, #T_53b03_row11_col15, #T_53b03_row12_col14, #T_53b03_row13_col15, #T_53b03_row14_col14, #T_53b03_row15_col15, #T_53b03_row16_col14, #T_53b03_row22_col14, #T_53b03_row25_col15 {
#   background-color: #B2D291;
#   color: #000;
# }
# #T_53b03_row0_col16, #T_53b03_row1_col15, #T_53b03_row5_col15, #T_53b03_row7_col16, #T_53b03_row18_col15, #T_53b03_row22_col15 {
#   background-color: #AFD190;
#   color: #000;
# }
# #T_53b03_row0_col17, #T_53b03_row2_col18, #T_53b03_row11_col18, #T_53b03_row15_col18, #T_53b03_row19_col17 {
#   background-color: #A1CB8C;
#   color: #000;
# }
# #T_53b03_row0_col18, #T_53b03_row13_col18, #T_53b03_row16_col17, #T_53b03_row18_col18, #T_53b03_row23_col17 {
#   background-color: #A5CD8D;
#   color: #000;
# }
# #T_53b03_row0_col19, #T_53b03_row6_col19, #T_53b03_row18_col20, #T_53b03_row22_col19 {
#   background-color: #99C88A;
#   color: #000;
# }
# #T_53b03_row0_col20, #T_53b03_row24_col20 {
#   background-color: #97C789;
#   color: #000;
# }
# #T_53b03_row0_col21, #T_53b03_row4_col21, #T_53b03_row10_col21, #T_53b03_row22_col22, #T_53b03_row24_col22 {
#   background-color: #91C588;
#   color: #000;
# }
# #T_53b03_row0_col22, #T_53b03_row7_col21, #T_53b03_row9_col22, #T_53b03_row21_col21, #T_53b03_row23_col21, #T_53b03_row24_col21 {
#   background-color: #8EC487;
#   color: #000;
# }
# #T_53b03_row0_col23, #T_53b03_row10_col24 {
#   background-color: #86C185;
#   color: #000;
# }
# #T_53b03_row0_col24, #T_53b03_row2_col23, #T_53b03_row4_col24, #T_53b03_row6_col23, #T_53b03_row7_col23, #T_53b03_row11_col24, #T_53b03_row15_col23, #T_53b03_row17_col23, #T_53b03_row22_col23, #T_53b03_row25_col23 {
#   background-color: #86C184;
#   color: #000;
# }
# #T_53b03_row0_col25 {
#   background-color: #7BBC81;
#   color: #000;
# }
# #T_53b03_row1_col0, #T_53b03_row5_col0, #T_53b03_row7_col0, #T_53b03_row22_col0 {
#   background-color: #F9EEA5;
#   color: #000;
# }
# #T_53b03_row1_col1, #T_53b03_row7_col1, #T_53b03_row16_col2, #T_53b03_row22_col2 {
#   background-color: #EEEAA2;
#   color: #000;
# }
# #T_53b03_row1_col3, #T_53b03_row5_col3, #T_53b03_row6_col3, #T_53b03_row10_col4, #T_53b03_row12_col4, #T_53b03_row18_col3, #T_53b03_row20_col3, #T_53b03_row22_col3 {
#   background-color: #E8E7A0;
#   color: #000;
# }
# #T_53b03_row1_col4, #T_53b03_row21_col4 {
#   background-color: #E5E6A0;
#   color: #000;
# }
# #T_53b03_row1_col5 {
#   background-color: #DEE39E;
#   color: #000;
# }
# #T_53b03_row1_col6, #T_53b03_row6_col6, #T_53b03_row7_col7, #T_53b03_row14_col6, #T_53b03_row25_col6 {
#   background-color: #D7E09B;
#   color: #000;
# }
# #T_53b03_row1_col7, #T_53b03_row8_col7, #T_53b03_row13_col9, #T_53b03_row23_col7, #T_53b03_row23_col8 {
#   background-color: #D1DE9A;
#   color: #000;
# }
# #T_53b03_row1_col8, #T_53b03_row12_col8 {
#   background-color: #D0DE99;
#   color: #000;
# }
# #T_53b03_row1_col9, #T_53b03_row2_col10, #T_53b03_row16_col10 {
#   background-color: #CADB98;
#   color: #000;
# }
# #T_53b03_row1_col10, #T_53b03_row9_col10 {
#   background-color: #C3D896;
#   color: #000;
# }
# #T_53b03_row1_col11, #T_53b03_row1_col12, #T_53b03_row2_col11, #T_53b03_row21_col11 {
#   background-color: #C1D895;
#   color: #000;
# }
# #T_53b03_row1_col13, #T_53b03_row1_col14, #T_53b03_row9_col13, #T_53b03_row10_col13, #T_53b03_row19_col14 {
#   background-color: #B4D392;
#   color: #000;
# }
# #T_53b03_row1_col16, #T_53b03_row15_col16, #T_53b03_row16_col15 {
#   background-color: #ACD08F;
#   color: #000;
# }
# #T_53b03_row1_col17, #T_53b03_row5_col17, #T_53b03_row6_col18, #T_53b03_row15_col17, #T_53b03_row23_col18 {
#   background-color: #A3CC8D;
#   color: #000;
# }
# #T_53b03_row1_col18, #T_53b03_row1_col19, #T_53b03_row13_col19, #T_53b03_row16_col19 {
#   background-color: #9CC98B;
#   color: #000;
# }
# #T_53b03_row1_col20, #T_53b03_row2_col20, #T_53b03_row6_col20, #T_53b03_row19_col19, #T_53b03_row22_col20 {
#   background-color: #98C88A;
#   color: #000;
# }
# #T_53b03_row1_col21, #T_53b03_row10_col20, #T_53b03_row15_col21, #T_53b03_row20_col21, #T_53b03_row25_col20 {
#   background-color: #94C688;
#   color: #000;
# }
# #T_53b03_row1_col22, #T_53b03_row2_col22, #T_53b03_row9_col20, #T_53b03_row11_col21 {
#   background-color: #92C588;
#   color: #000;
# }
# #T_53b03_row1_col23, #T_53b03_row3_col23, #T_53b03_row18_col23, #T_53b03_row21_col23, #T_53b03_row24_col23 {
#   background-color: #89C285;
#   color: #000;
# }
# #T_53b03_row1_col24 {
#   background-color: #88C185;
#   color: #000;
# }
# #T_53b03_row1_col25 {
#   background-color: #7CBD81;
#   color: #000;
# }
# #T_53b03_row2_col1, #T_53b03_row19_col1, #T_53b03_row21_col2 {
#   background-color: #F1EBA3;
#   color: #000;
# }
# #T_53b03_row2_col2, #T_53b03_row11_col3, #T_53b03_row25_col3 {
#   background-color: #E9E8A1;
#   color: #000;
# }
# #T_53b03_row2_col3, #T_53b03_row10_col2, #T_53b03_row15_col3, #T_53b03_row15_col4, #T_53b03_row21_col3 {
#   background-color: #E9E7A1;
#   color: #000;
# }
# #T_53b03_row2_col4, #T_53b03_row3_col3, #T_53b03_row7_col4, #T_53b03_row8_col4 {
#   background-color: #E5E69F;
#   color: #000;
# }
# #T_53b03_row2_col5, #T_53b03_row19_col6, #T_53b03_row24_col5 {
#   background-color: #DBE29D;
#   color: #000;
# }
# #T_53b03_row2_col6, #T_53b03_row10_col5 {
#   background-color: #DBE29C;
#   color: #000;
# }
# #T_53b03_row2_col7, #T_53b03_row5_col6, #T_53b03_row7_col6, #T_53b03_row8_col6, #T_53b03_row10_col6, #T_53b03_row10_col7, #T_53b03_row12_col6, #T_53b03_row13_col7, #T_53b03_row16_col6, #T_53b03_row16_col7, #T_53b03_row18_col6, #T_53b03_row19_col7, #T_53b03_row21_col7, #T_53b03_row22_col6 {
#   background-color: #D9E19C;
#   color: #000;
# }
# #T_53b03_row2_col8, #T_53b03_row11_col8, #T_53b03_row15_col9, #T_53b03_row25_col9 {
#   background-color: #CCDC98;
#   color: #000;
# }
# #T_53b03_row2_col12, #T_53b03_row5_col11 {
#   background-color: #C2D895;
#   color: #000;
# }
# #T_53b03_row2_col14, #T_53b03_row6_col13, #T_53b03_row15_col14, #T_53b03_row17_col13, #T_53b03_row17_col14 {
#   background-color: #B8D493;
#   color: #000;
# }
# #T_53b03_row2_col15, #T_53b03_row4_col14, #T_53b03_row21_col14 {
#   background-color: #B0D190;
#   color: #000;

# %%
pretty_pandas(
    test_df, index='show', font_size=11, header_size=12, mymax=100,
    # fill_palette=['#FFFFDD','#DAECB8','#87C6BD','#4B96BE','#2E4C9B','#0D1D55'],
    fill_palette=['#e8f6b1', '#b2e1b6', '#65c3bf', '#2ca1c2', '#216daf', '#253997','#000'],
    rows = list(test_df.index)[8:18], #['Starfruit','Plum','Banana','Raspberry'],
    columns = ['B','C','D','E','F','G','H','I'],
    default_fill_color = '#F9F9F9',
    default_text_color = '#DDDDE4',
)
# Out:
# <style type="text/css">
# #T_35dbd_ tr {
#   background-color: white !important;
# }
# #T_35dbd_row0_col0, #T_35dbd_row0_col1, #T_35dbd_row0_col2, #T_35dbd_row0_col3, #T_35dbd_row0_col4, #T_35dbd_row0_col5, #T_35dbd_row0_col6, #T_35dbd_row0_col7, #T_35dbd_row0_col8, #T_35dbd_row0_col9, #T_35dbd_row0_col10, #T_35dbd_row0_col11, #T_35dbd_row0_col12, #T_35dbd_row0_col13, #T_35dbd_row0_col14, #T_35dbd_row0_col15, #T_35dbd_row0_col16, #T_35dbd_row0_col17, #T_35dbd_row0_col18, #T_35dbd_row0_col19, #T_35dbd_row0_col20, #T_35dbd_row0_col21, #T_35dbd_row0_col22, #T_35dbd_row0_col23, #T_35dbd_row0_col24, #T_35dbd_row0_col25, #T_35dbd_row1_col0, #T_35dbd_row1_col1, #T_35dbd_row1_col2, #T_35dbd_row1_col3, #T_35dbd_row1_col4, #T_35dbd_row1_col5, #T_35dbd_row1_col6, #T_35dbd_row1_col7, #T_35dbd_row1_col8, #T_35dbd_row1_col9, #T_35dbd_row1_col10, #T_35dbd_row1_col11, #T_35dbd_row1_col12, #T_35dbd_row1_col13, #T_35dbd_row1_col14, #T_35dbd_row1_col15, #T_35dbd_row1_col16, #T_35dbd_row1_col17, #T_35dbd_row1_col18, #T_35dbd_row1_col19, #T_35dbd_row1_col20, #T_35dbd_row1_col21, #T_35dbd_row1_col22, #T_35dbd_row1_col23, #T_35dbd_row1_col24, #T_35dbd_row1_col25, #T_35dbd_row2_col0, #T_35dbd_row2_col1, #T_35dbd_row2_col2, #T_35dbd_row2_col3, #T_35dbd_row2_col4, #T_35dbd_row2_col5, #T_35dbd_row2_col6, #T_35dbd_row2_col7, #T_35dbd_row2_col8, #T_35dbd_row2_col9, #T_35dbd_row2_col10, #T_35dbd_row2_col11, #T_35dbd_row2_col12, #T_35dbd_row2_col13, #T_35dbd_row2_col14, #T_35dbd_row2_col15, #T_35dbd_row2_col16, #T_35dbd_row2_col17, #T_35dbd_row2_col18, #T_35dbd_row2_col19, #T_35dbd_row2_col20, #T_35dbd_row2_col21, #T_35dbd_row2_col22, #T_35dbd_row2_col23, #T_35dbd_row2_col24, #T_35dbd_row2_col25, #T_35dbd_row3_col0, #T_35dbd_row3_col1, #T_35dbd_row3_col2, #T_35dbd_row3_col3, #T_35dbd_row3_col4, #T_35dbd_row3_col5, #T_35dbd_row3_col6, #T_35dbd_row3_col7, #T_35dbd_row3_col8, #T_35dbd_row3_col9, #T_35dbd_row3_col10, #T_35dbd_row3_col11, #T_35dbd_row3_col12, #T_35dbd_row3_col13, #T_35dbd_row3_col14, #T_35dbd_row3_col15, #T_35dbd_row3_col16, #T_35dbd_row3_col17, #T_35dbd_row3_col18, #T_35dbd_row3_col19, #T_35dbd_row3_col20, #T_35dbd_row3_col21, #T_35dbd_row3_col22, #T_35dbd_row3_col23, #T_35dbd_row3_col24, #T_35dbd_row3_col25, #T_35dbd_row4_col0, #T_35dbd_row4_col1, #T_35dbd_row4_col2, #T_35dbd_row4_col3, #T_35dbd_row4_col4, #T_35dbd_row4_col5, #T_35dbd_row4_col6, #T_35dbd_row4_col7, #T_35dbd_row4_col8, #T_35dbd_row4_col9, #T_35dbd_row4_col10, #T_35dbd_row4_col11, #T_35dbd_row4_col12, #T_35dbd_row4_col13, #T_35dbd_row4_col14, #T_35dbd_row4_col15, #T_35dbd_row4_col16, #T_35dbd_row4_col17, #T_35dbd_row4_col18, #T_35dbd_row4_col19, #T_35dbd_row4_col20, #T_35dbd_row4_col21, #T_35dbd_row4_col22, #T_35dbd_row4_col23, #T_35dbd_row4_col24, #T_35dbd_row4_col25, #T_35dbd_row5_col0, #T_35dbd_row5_col1, #T_35dbd_row5_col2, #T_35dbd_row5_col3, #T_35dbd_row5_col4, #T_35dbd_row5_col5, #T_35dbd_row5_col6, #T_35dbd_row5_col7, #T_35dbd_row5_col8, #T_35dbd_row5_col9, #T_35dbd_row5_col10, #T_35dbd_row5_col11, #T_35dbd_row5_col12, #T_35dbd_row5_col13, #T_35dbd_row5_col14, #T_35dbd_row5_col15, #T_35dbd_row5_col16, #T_35dbd_row5_col17, #T_35dbd_row5_col18, #T_35dbd_row5_col19, #T_35dbd_row5_col20, #T_35dbd_row5_col21, #T_35dbd_row5_col22, #T_35dbd_row5_col23, #T_35dbd_row5_col24, #T_35dbd_row5_col25, #T_35dbd_row6_col0, #T_35dbd_row6_col1, #T_35dbd_row6_col2, #T_35dbd_row6_col3, #T_35dbd_row6_col4, #T_35dbd_row6_col5, #T_35dbd_row6_col6, #T_35dbd_row6_col7, #T_35dbd_row6_col8, #T_35dbd_row6_col9, #T_35dbd_row6_col10, #T_35dbd_row6_col11, #T_35dbd_row6_col12, #T_35dbd_row6_col13, #T_35dbd_row6_col14, #T_35dbd_row6_col15, #T_35dbd_row6_col16, #T_35dbd_row6_col17, #T_35dbd_row6_col18, #T_35dbd_row6_col19, #T_35dbd_row6_col20, #T_35dbd_row6_col21, #T_35dbd_row6_col22, #T_35dbd_row6_col23, #T_35dbd_row6_col24, #T_35dbd_row6_col25, #T_35dbd_row7_col0, #T_35dbd_row7_col1, #T_35dbd_row7_col2, #T_35dbd_row7_col3, #T_35dbd_row7_col4, #T_35dbd_row7_col5, #T_35dbd_row7_col6, #T_35dbd_row7_col7, #T_35dbd_row7_col8, #T_35dbd_row7_col9, #T_35dbd_row7_col10, #T_35dbd_row7_col11, #T_35d ...

# %%
pretty_pandas(
    test_df, index='show', font_size=11, header_size=12, mymin=4, mymax=18,
    fill_palette=[list(sns.color_palette('YlOrRd').as_hex()),[]],
    default_fill_color = '#F9F9F9',
    default_text_color = '#555',
)
# Out:
# <style type="text/css">
# #T_9deb7_ tr {
#   background-color: white !important;
# }
# #T_9deb7_row0_col0, #T_9deb7_row0_col1, #T_9deb7_row0_col2, #T_9deb7_row0_col3, #T_9deb7_row0_col17, #T_9deb7_row0_col18, #T_9deb7_row0_col19, #T_9deb7_row0_col20, #T_9deb7_row0_col21, #T_9deb7_row0_col22, #T_9deb7_row0_col23, #T_9deb7_row0_col24, #T_9deb7_row0_col25, #T_9deb7_row1_col0, #T_9deb7_row1_col1, #T_9deb7_row1_col2, #T_9deb7_row1_col17, #T_9deb7_row1_col18, #T_9deb7_row1_col19, #T_9deb7_row1_col20, #T_9deb7_row1_col21, #T_9deb7_row1_col22, #T_9deb7_row1_col23, #T_9deb7_row1_col24, #T_9deb7_row1_col25, #T_9deb7_row2_col0, #T_9deb7_row2_col1, #T_9deb7_row2_col2, #T_9deb7_row2_col17, #T_9deb7_row2_col18, #T_9deb7_row2_col19, #T_9deb7_row2_col20, #T_9deb7_row2_col21, #T_9deb7_row2_col22, #T_9deb7_row2_col23, #T_9deb7_row2_col24, #T_9deb7_row2_col25, #T_9deb7_row3_col0, #T_9deb7_row3_col1, #T_9deb7_row3_col2, #T_9deb7_row3_col18, #T_9deb7_row3_col19, #T_9deb7_row3_col20, #T_9deb7_row3_col21, #T_9deb7_row3_col22, #T_9deb7_row3_col23, #T_9deb7_row3_col24, #T_9deb7_row3_col25, #T_9deb7_row4_col0, #T_9deb7_row4_col
row13_col21, #T_9deb7_row13_col22, #T_9deb7_row13_col23, #T_9deb7_row13_col24, #T_9deb7_row13_col25, #T_9deb7_row14_col0, #T_9deb7_row14_col1, #T_9deb7_row14_col2, #T_9deb7_row14_col3, #T_9deb7_row14_col18, #T_9deb7_row14_col19, #T_9deb7_row14_col20, #T_9deb7_row14_col21, #T_9deb7_row14_col22, #T_9deb7_row14_col23, #T_9deb7_row14_col24, #T_9deb7_row14_col25, #T_9deb7_row15_col0, #T_9deb7_row15_col1, #T_9deb7_row15_col2, #T_9deb7_row15_col3, #T_9deb7_row15_col17, #T_9deb7_row15_col18, #T_9deb7_row15_col19, #T_9deb7_row15_col20, #T_9deb7_row15_col21, #T_9deb7_row15_col22, #T_9deb7_row15_col23, #T_9deb7_row15_col24, #T_9deb7_row15_col25, #T_9deb7_row16_ ...
#   background-color: #F9F9F9;
#   color: #555;
# }
# #T_9deb7_row0_col4, #T_9deb7_row17_col5 {
#   background-color: #FFDD85;
#   color: #000;
# }
# #T_9deb7_row0_col5, #T_9deb7_row16_col5, #T_9deb7_row20_col5 {
#   background-color: #FED87C;
#   color: #000;
# }
# #T_9deb7_row0_col6 {
#   background-color: #FECA67;
#   color: #000;
# }
# #T_9deb7_row0_col7, #T_9deb7_row18_col8, #T_9deb7_row24_col7 {
#   background-color: #FEAF50;
#   color: #000;
# }
# #T_9deb7_row0_col8, #T_9deb7_row2_col9, #T_9deb7_row21_col8 {
#   background-color: #FEA749;
#   color: #000;
# }
# #T_9deb7_row0_col9 {
#   background-color: #FD8B3D;
#   color: #000;
# }
# #T_9deb7_row0_col10, #T_9deb7_row8_col11 {
#   background-color: #FC7336;
#   color: #000;
# }
# #T_9deb7_row0_col11, #T_9deb7_row22_col11 {
#   background-color: #FA6230;
#   color: #000;
# }
# #T_9deb7_row0_col12, #T_9deb7_row20_col12 {
#   background-color: #FC6732;
#   color: #000;
# }
# #T_9deb7_row0_col13 {
#   background-color: #F5502B;
#   color: #000;
# }
# #T_9deb7_row0_col14, #T_9deb7_row2_col13 {
#   background-color: #F03E26;
#   color: #FFF;
# }
# #T_9deb7_row0_col15, #T_9deb7_row10_col14, #T_9deb7_row13_col15 {
#   background-color: #E72620;
#   color: #FFF;
# }
# #T_9deb7_row0_col16, #T_9deb7_row7_col16 {
#   background-color: #DE1D22;
#   color: #FFF;
# }
# #T_9deb7_row1_col3, #T_9deb7_row10_col4 {
#   background-color: #FFE897;
#   color: #000;
# }
# #T_9deb7_row1_col4, #T

# %%
#.hide_index()

#cols=[[['sns_yellow','sns_green','sns_blue'],'shade']],
#[['sns_blue','sns_green'],'shade',['A','C']]]

#).format('{:.3f}').hide_index()

#.highlight_max(color='lightgreen')
#.bar(subset='C',color='#AAC')

# %%
# USE CASES

# positive and negative values
# using logarithmic/exponential color scales
# finding outliers

# %%
def apply_colors(col, default_fill_color='#FFF', default_text_color='#000', default_border='', default_fill_text_colors=['#000','#FFF'],
                 thresholds=None, fill_palette=None, text_palette=None, rows=None, columns=None, mymin=None, mymax=None):

    fill_palette = [None if f is None else list(get_rgb_colors(p) for p in f) for f in fill_palette]
    text_palette = [None if t is None else list(get_rgb_colors(p) for p in t) for t in text_palette]
    rgb_fill_vals,rgb_text_vals,fill_styles,default_text_styles,active_text_styles = [],[],[],[],[]
    default = 'background-color: '+default_fill_color+'; color: '+default_text_color+'; border: '+default_border
    styles = [default for j in range(len(col.values))]
    text_styles = ['' for j in range(len(col.values))]
    
    for i in range(len(fill_palette)):
        if fill_palette[i] is not None:
            if len(fill_palette[i]) == 1: # if the palette length is just 1 we just apply it globally - the trivial case
                rgb_fill_vals += [[fill_palette[i][0] for c in col.values]]
            else: # if the palette length is greater than 1, we assign each value a bespoke color based on its position in the full range
                fill_thresholds = divide_range(mymin[i], mymax[i], len(fill_palette[i]), thresholds)
                fill_quantiles = make_quantiles(col.values, fill_palette[i], mymin[i], mymax[i])
                rgb_fill_vals += [[generate_color(c, fill_thresholds[q:q+2], fill_palette[i][q:q+2]) for c,q in zip(col.values, fill_quantiles)]]
        else:
            rgb_fill_vals += [[None for c in col.values]]

        if text_palette[i] is not None:
            if len(text_palette[i]) == 1:
                rgb_text_vals += [[text_palette[i][0] for c in col.values]]
            else:
                text_thresholds = divide_range(mymin[i], mymax[i], len(text_palette[i]))
                text_quantiles = make_quantiles(col.values, text_palette[i], mymin[i], mymax[i])
                rgb_text_vals += [[generate_color(c, text_thresholds[q:q+2], text_palette[i][q:q+2]) for c,q in zip(col.values, text_quantiles)]]
        else:
            rgb_text_vals += [[None for c in col.values]]

        fill_styles += [['background-color: '+('' if fill_palette[i] is None else '#'+''.join([make_hex_color(c) for c in v])) for v in rgb_fill_vals[-1]]]
        default_text_styles += [['color: '+('' if fill_palette[i] is None else (default_fill_text_colors[0] if luminosity(v)>=100 else default_fill_text_colors[1])) for v in rgb_fill_vals[-1]]]
        text_styles = ['color: #'+(text_styles[j] if text_palette[i] is None else ''.join([make_hex_color(c) for c in rgb_text_vals[-1][j]])) for j in range(len(col.values))]
        
        styles = ['; '.join([fill_styles[i][j],default_text_styles[i][j],text_styles[j]]) if (mymin[i] <= col.values[j] <= mymax[i]) and
                  (col.name in columns[i]) and (j in rows[i]) else styles[j] for j in range(len(col.values))]
    
    return styles

# %%
def pretty_pandas(df, fill_palette=None, text_palette=None, rows=None, columns=None, index='show', group=None, font_size=None,
                  thresholds=None, header_size=None, default_fill_color='#FFF', default_text_color='#000', default_border='',
                  default_fill_text_colors=['#000','#FFF'], bg='white', mymin=None, mymax=None, configs=None):
    """Generate efficient dataframe styling with fully customizable inputs.
    Keyword arguments:

    todo
    """
    sdf = df.style
    rows_all,columns_all = list(df.index),list(df.columns)

    def absent():
        return None
    if configs is not None:
        configs_default = [defaultdict(absent) for c in configs]
        for c in range(len(configs)):
            for i in configs[c].keys():
                configs_default[c][i] = configs[c][i]
        fill_palette = [c['fill_palette'] for c in configs_default]
        text_palette = [c['text_palette'] for c in configs_default]
        rows = [c['rows'] if c['rows'] is not None else rows_all for c in configs_default]
        row_indices = [list(rows_all.index(i) for i in r) for r in rows]
        columns = [c['columns'] if c['columns'] is not None else columns_all for c in configs_default]
        mymin, mymax = [],[]
        for i,c in enumerate(configs_default):
            df_subset = df.loc[rows[i],columns[i]]
            mymin.append(type_format(df_subset.values,c['mymin'],c['number']) if c['mymin'] is not None else np.min(df_subset.values))
            mymax.append(type_format(df_subset.values,c['mymax'],c['number']) if c['mymax'] is not None else np.max(df_subset.values))
        # mymax = [max(mymin[m]+1,mymax[m]) for m in range(len(mymax))] # to prevent any divide by zero later on

    else:
        if mymin is None: mymin=np.min(df.values)
        if mymax is None: mymax=np.max(df.values)
        if rows is None: rows = rows_all
        if columns is None: columns = columns_all
        mymin,mymax,rows,columns = [mymin],[mymax],[rows],[columns]

    if index=='hide': sdf.hide_index()
    if header_size is None: header_size=font_size

    sdf.apply(apply_colors, default_fill_color=default_fill_color, default_text_color=default_text_color,
              default_fill_text_colors=default_fill_text_colors, thresholds=thresholds, default_border=default_border,
              fill_palette=fill_palette, text_palette=text_palette, rows=row_indices, columns=columns, mymin=mymin, mymax=mymax, axis=0)

    return sdf.format('{:.3f}').set_table_styles([{'selector':'tr','props':[('background-color',bg+' !important')]}])

    # sdf.set_properties(**{'font-size': str(font_size)+'pt'})
    # .set_table_styles([{'selector': 'th', 'props': [('font-size', str(22)+'pt !important')]}])

# %%
def make_palette(*args,number='pct',palette=['white','red','yellow','green','blue'],**kwargs):
    configs = []
    if len(args)==2 or len(args)>=len(palette):
        configs.extend([
            {'fill_palette': palette[:1], 'mymax': args[0], 'number': number},
            {'fill_palette': palette[-1:], 'mymin': args[-1], 'number': number}
        ])
    else:
        if number=='pct':
            args = [0]+list(args)+[100]
        else:
            args = [-np.inf]+list(args)+[np.inf]
    for i in range(len(args)-1):
        configs.append(
            {
                'fill_palette': palette if len(args)==2 else palette[i:i+2],
                'mymin': args[i],
                'mymax': args[i+1],
                'number': number
            }
        )
    for c in configs:
        for k in kwargs.keys(): c[k]=kwargs[k]
    return configs

# %%
pretty_pandas(
    test_df,
    index='show',
    font_size=11,
    header_size=12,
    default_fill_color='#F9F9FF',
    default_text_color='#555',
    #default_border='1px solid #CCC',
    configs=make_palette(50,palette=['red','yellow'],number='pct',columns=['A','B','C','D','E','F','G','H'])
)
# Out:
# <style type="text/css">
# #T_52055_ tr {
#   background-color: white !important;
# }
# #T_52055_row0_col0, #T_52055_row8_col0 {
#   background-color: #ED9780;
#   color: #000;
#   color: #;
# }
# #T_52055_row0_col1, #T_52055_row23_col0 {
#   background-color: #EFA184;
#   color: #000;
#   color: #;
# }
# #T_52055_row0_col2, #T_52055_row0_col3, #T_52055_row4_col3 {
#   background-color: #F9DC9E;
#   color: #000;
#   color: #;
# }
, #T_52055_row9_col9, #T_52055_row9_col10, #T_52055_row9_col11, #T_52055_row9_col12, #T_52055_row9_col13, #T_52055_row9_col14, #T_52055_row9_col15, #T_52055_row9_col16, #T_52055_row9_col17, #T_52055_row9_col18, #T_52055_row9_col19, #T_52055_row9_col20, #T_52055_row9_col21, #T_52055_row9_col22, #T_52055_row9_col23, #T_52055_row9_col24, #T_52055_row9_col25, #T_52055_row10_col8, #T_52055_row10_col9, #T_52055_row10_col10, #T_52055_row10_col11, #T_52055_row10_col12, #T_52055_row10_col13, #T_52055_row10_col14, #T_52055_row10_col15, #T_52055_row10_col16, #T_52055_row10_col17, #T_52055_row10_col18,  ...

# %%
configs=[
    {
        'mymin': 10,
        #'mymax': 18,
        'fill_palette': list(sns.color_palette('YlOrRd').as_hex()),
        #'text_palette': ['#DDD','#500','#000'],
        #'rows': list(test_df.index)[8:18],
        'columns': ['B','C','D','E','F','G','H','I','J','K','L','M']
    },
    {
        #'mymin': 20,
        'mymax': 10,
        'fill_palette': ['#800'], # ['#e8f6b1', '#b2e1b6', '#65c3bf', '#2ca1c2', '#216daf', '#253997', '#000'],
        #'text_palette': ['#AAF','#500','#000'],
        #'rows': list(test_df.index)[2:11],
        #'columns': ['L','M','N']
    },
    {
        'mymin': 9,
        'mymax': 18,
        'fill_palette': ['#DDD'], #['#e8f6b1', '#b2e1b6', '#65c3bf', '#2ca1c2', '#216daf', '#253997', '#000'],
        #'text_palette': ['#AAF','#500','#000'],
        #'rows': list(test_df.index)[2:11],
        #'columns': ['L','M','N']
    }
]

pretty_pandas(
    test_df+5,
    index='show',
    font_size=11,
    header_size=12,
    default_fill_color='#F9F9FF',
    default_text_color='#555',
    # default_border='1px solid #CCC',
    configs=configs # this would be an alternative to passing values directly
)
# Out:
# <style type="text/css">
# #T_01b60_ tr {
#   background-color: white !important;
# }
# #T_01b60_row0_col0, #T_01b60_row0_col1, #T_01b60_row0_col2, #T_01b60_row0_col3, #T_01b60_row1_col0, #T_01b60_row1_col1, #T_01b60_row1_col2, #T_01b60_row2_col0, #T_01b60_row2_col1, #T_01b60_row2_col2, #T_01b60_row3_col0, #T_01b60_row3_col1, #T_01b60_row3_col2, #T_01b60_row4_col0, #T_01b60_row4_col1, #T_01b60_row4_col2, #T_01b60_row4_col3, #T_01b60_row5_col0, #T_01b60_row5_col1, #T_01b60_row5_col2, #T_01b60_row6_col0, #T_01b60_row6_col1, #T_01b60_row6_col2, #T_01b60_row7_col0, #T_01b60_row7_col1, #T_01b60_row7_col2, #T_01b60_row7_col3, #T_01b60_row8_col0, #T_01b60_row8_col1, #T_01b60_row8_col2, #T_01b60_row9_col0, #T_01b60_row9_col1, #T_01b60_row9_col2, #T_01b60_row10_col0, #T_01b60_row10_col1, #T_01b60_row10_col2, #T_01b60_row10_col3, #T_01b60_row11_col0, #T_01b60_row11_col1, #T_01b60_row11_col2, #T_01b60_row11_col3, #T_01b60_row12_col0, #T_01b60_row12_col1, #T_01b60_row12_col2, #T_01b60_row13_col0, #T_01b60_row13_col1, #T_01b60_row13_col2, #T_01b60_row14_col0, #T_01b60_row14_col1, #T_01b60_row14_col2, #T_01b60_row14_col3, #T_01b60_row15_col0, #T_01b60_row15_col1, #T_01b60_row15_col2, #T_01b60_row15_col3, #T_01b60_row16_col0, #T_01b60_row16_col1, #T_01b60_row16_col2, #T_01b60_row16_col3, #T_01b60_row17_col0, #T_01b60_row17_col1, #T_01b60_row17_col2, #T_01b60_row17_col3, #T_01b60_row18_col0, #T_01b60_row18_col1, #T_01b60_row18_col2, #T_01b60_row19_col0, #T_01b60_row19_col1, #T_01b60_row19_col2, #T_01b60_row20_col0, #T_01b60_row20_col1, #T_01b60_row20_col2, #T_01b60_row21_col0, #T_01b60_row21_col1, #T_01b60_row21_col2, #T_01b60_row21_col3, #T_01b60_row22_col0, #T_01b60_row22_col1, #T_01b60_row22_col2, #T_01b60_row23_col0, #T_01b60_row23_col1, #T_01b60_row23_col2, #T_01b60_row23_col3, #T_01b60_row24_col0, #T_01b60_row24_col1, #T_01b60_row24_col2, #T_01b60_row24_col3, #T_01b60_row25_col0, #T_01b60_row25_col1, #T_01b60_row25_col2, #T_01b60_row25_col3 {
#   background-color: #880000;
#   color: #FFF;
#   color: #color;
# }
# #T_01b60_row0_col4, #T_01b60_row0_col5, #T_01b60_row0_col6, #T_01b60_row0_col7, #T_01b60_row0_col8, #T_01b60_row0_col9, #T_01b60_row0_col10, #T_01b60_row0_col11, #T_01b60_row0_col12, #T_01b60_row1_col3, #T_01b60_row1_col4, #T_01b60_row1_col5, #T_01b60_row1_col6, #T_01b60_row1_col7, #T_01b60_row1_col8, #T_01b60_row1_col9, #T_01b60_row1_col10, #T_01b60_row1_col11, #T_01b60_row1_col12, #T_01b60_row2_col3, #T_01b60_row2_col4, #T_01b60_row2_col5, #T_01b60_row2_col6, #T_01b60_row2_col7, #T_01b60_row2_col8, #T_01b60_row2_col9, #T_01b60_row2_col10, #T_01b60_row2_col11, #T_01b60_row2_col12, #T_01b60_row3_col3, #T_01b60_row3_col4, #T_01b60_row3_col5, #T_01b60_row3_col6, #T_01b60_row3_col7, #T_01b60_row3_col8, #T_01b60_row3_col9, #T_01b60_row3_col10, #T_01b60_row3_col11, #T_01b60_row4_col4, #T_01b60_row4_col5, #T_01b60_row4_col6, #T_01b60_row4_col7, #T_01b60_row4_col8, #T_01b60_row4_col9, #T_01b60_row4_col10, #T_01b60_row4_col11, #T_01b60_row5_col3, #T_01b60_row5_col4, #T_01b60_row5_col5, #T_01b60_row5_col6, #T_01b60_row5_col7, #T_01b60_row5_col8, #T_01b60_row5_col9, #T_01b60_row5_col10, #T_01b60_row5_col11, #T_01b60_row5_col12, #T_01b60_row6_col3, #T_01b60_row6_col4, #T_01b60_row6_col5, #T_01b60_row6_col6, #T_01b60_row6_col7, #T_01b60_row6_col8, #T_01b60_row6_col9, #T_01b60_row6_col10, #T_01b60_row6_col11, #T_01b60_row7_col4, #T_01b60_row7_col5, #T_01b60_row7_col6, #T_01b60_row7_col7, #T_01b60_row7_col8, #T_
#   background-color: #DDDDDD;
#   color: #000;
#   color: #color;
# }
# #T_01b60_row0_col13, #T_01b60_row0_col14, #T_01b60_row0_col15, #T_01b60_row0_col16, #T_01b60_row0_col17, #T_01b60_row0_col18, #T_01b60_row0_col19, #T_01b60_row0_col20, #T_01b60_row0_col21, #T_01b60_row0_col22, #T_01b60_row0_col23, #T_01b60_row0_col24, #T_01b60_row0_col25, #T_01b60_row1_col13, #T_01b60_row1_col14, #T_01b60_row1_col15, #T_01b60_row1_col16, #T_01b60_row1_col17, #T_01b60_row1_col18, #T_01b60_row1_col19, #T_01b60_row1_col20, #T_01b60_row1_col21, #T_01b60_row1_col22, #T_01b60_row1_col23, #T_01b60_row1_col24, #T_01b60_row1_col25, #T_01b60_row2_col13, #T_01b60_row2_col14, #T_01b60_row2_col15, #T_01b60_row2_col16, #T_01b60_row2_col17, #T_01b60_row2_col18, #T_01b60_row2_col19, #T_01b60_row2_col20, #T_01b60_row2_col21, #T_01b60_row2_col22, #T_01b60_row2_col23, #T_01b60_row2_col24, #T_01b60_row2_col25, #T_01b60_row3_col13, #T_01b60_row3_col14, #T_01b60_row3_col15, #T_01b60_row3_col16, #T_01b60_row3_col17, #T_01b60_row3_col18, #T_01b60_row3_col19, #T_01b60_row3_col20, #T_01b60_row3_col21, #T_01b60_row3_col22, #T_01b60_row3_col23, #T_01b60_row3_col24, #

# %%
#### SOME PREDEFINED CONFIGS FOR TABLES

# %%
pos_neg_fill=[
    {
        'mymin': 0,
        'fill_palette': ['green']
    },
    {
        'mymax': 0,
        'fill_palette': ['red']
    },
    {
        'mymin': 0,
        'mymax': 0,
        'fill_palette': ['white']
    }
]

pretty_pandas(
    test_df-5.849,
    configs=pos_neg_fill
)
# Out:
# <style type="text/css">
# #T_1e524_ tr {
#   background-color: white !important;
# }
# #T_1e524_row0_col0, #T_1e524_row0_col1, #T_1e524_row0_col2, #T_1e524_row0_col3, #T_1e524_row0_col4, #T_1e524_row0_col5, #T_1e524_row1_col0, #T_1e524_row1_col1, #T_1e524_row1_col2, #T_1e524_row1_col3, #T_1e524_row1_col4, #T_1e524_row2_col0, #T_1e524_row2_col1, #T_1e524_row2_col2, #T_1e524_row2_col3, #T_1e524_row2_col4, #T_1e524_row3_col0, #T_1e524_row3_col1, #T_1e524_row3_col2, #T_1e524_row3_col3, #T_1e524_row3_col4, #T_1e524_row4_col0, #T_1e524_row4_col1, #T_1e524_row4_col2, #T_1e524_row4_col3, #T_1e524_row4_col4, #T_1e524_row5_col0, #T_1e524_row5_col1, #T_1e524_row5_col2, #T_1e524_row5_col3, #T_1e524_row5_col4, #T_1e524_row6_col0, #T_1e524_row6_col1, #T_1e524_row6_col2, #T_1e524_row6_col3, #T_1e524_row6_col4, #T_1e524_row6_col5, #T_1e524_row7_col0, #T_1e524_row7_col1, #T_1e524_row7_col2, #T_1e524_row7_col3, #T_1e524_row7_col4, #T_1e524_row8_col0, #T_1e524_row8_col1, #T_1e524_row8_col2, #T_1e524_row8_col3, #T_1e524_row8_col4, #T_1e524_row9_col0, #T_1e524_row9_col1, #T_1e524_row9_col2, #T_1e524_row9_col3, #T_1e524_row9_col4, #T_1e524_row9_col5, #T_1e524_row10_col0, #T_1e524_row10_col1, #T_1e524_row10_col2, #T_1e524_row10_col3, #T_1e524_row10_col4, #T_1e524_row11_col0, #T_1e524_row11_col1, #T_1e524_row11_col2, #T_1e524_row11_col3, #T_1e524_row11_col4, #T_1e524_row12_col0, #T_1e524_row12_col1, #T_1e524_row12_col2, #T_1e524_row12_col3, #T_1e524_row12_col4, #T_1e524_row13_col0, #T_1e524_row13_col1, #T_1e524_row13_col2, #T_1e524_row13_col3, #T_1e524_row13_col4, #T_1e524_row14_col0, #T_1e524_row14_col1, #T_1e524_row14_col2, #T_1e524_row14_col3, #T_1e524_row14_col4, #T_1e524_row15_col0, #T_1e524_row15_col1, #T_1e524_row15_col2, #T_1e524_row15_col3, #T_1e524_row15_col4, #T_1e524_row16_col0, #T_1e524_row16_col1, #T_1e524_row16_col2, #T_1e524_row16_col3, #T_1e524_row16_col4, #T_1e524_row16_col5, #T_1e524_row17_col0, #T_1e524_row17_col1, #T_1e524_row17_col2, #T_1e524_row17_col3, #T_1e524_row17_col4, #T_1e524_row17_col5, #T_1e524_row18_col0, #T_1e524_row18_col1, #T_1e524_row18_col2, #T_1e524_row18_col3, #T_1e524_row18_col4, #T_1e524_row18_col5, #T_1e524_row19_col0, #T_1e524_row19_col1, #T_1e524_row19_col2, #T_1e524_row19_col3, #T_1e524_row19_col4, #T_1e524_row20_col0, #T_1e524_row20_col1, #T_1e524_row20_col2, #T_1e524_row20_col3, #T_1e524_row20_col4, #T_1e524_row20_col5, #T_1e524_row21_col0, #T_1e524_row21_col1, #T_1e524_row21_col2, #T_1e524_row21_col3, #T_1e524_row21_col4, #T_1e524_row21_col5, #T_1e524_row22_col0, #T_1e524_row22_col1, #T_1e524_row22_col2, #T_1e524_row22_col3, #T_1e524_row22_col4, #T_1e524_row23_col0, #T_1e524_row23_col1, #T_1e524_row23_col2, #T_1e524_row23_col3, #T_1e524_row23_col4, #T_1e524_row24_col0, #T_1e524_row24_col1, #T_1e524_row24_col2, #T_1e524_row24_col3, #T_1e524_row24_col4, #T_1e524_row25_col0, #T_1e524_row25_col1, #T_1e524_row25_col2, #T_1e524_row25_col3 {
#   background-color: #E77270;
#   color: #000;
#   color: #color;
# }
# #T_1e524_row0_col6, #T_1e524_row0_col7, #T_1e524_row0_col8, #T_1e524_row0_col9, #T_1e524_row0_col10, #T_1e524_row0_col11, #T_1e524_row0_col12, #T_1e524_row0_col13, #T_1e524_row0_col14, #T_1e524_row0_col15, #T_1e524_row0_col16, #T_1e524_row0_col17, #T_1e524_row0_col18, #T_1e524_row0_col19, #T_1e524_row0_col20, #T_1e524_row0_col21, #T_1e524_row0_col22, #T_1e524_row0_col23, #T_1e524_row0_col24, #T_1e524_row0_col25, #T_1e524_row1_col5, #T_1e
row6_col20, #T_1e524_row6_col21, #T_1e524_row6_col22, #T_1e524_row6_col23, #T_1e524_row6_col24, #T_1e524_row6_col25, #T_1e524_row7_col5, #T_1e524_row7_col6, #T_1e524_row7_col7, #T_1e524_row7_col8, #T_1e524_row7_col9, #T_1e524_row7_col10, #T_1e524_row7_col11, #T_1e524_row7_col12, #T_1e524_row7_col13, #T_1e524_row7_col14, #T_1e524_row7_col15, #T_1e524_row7_col16, #T_1e524_row7_col17, #T_1e524_row7_col18, #T_1e524_row7_col19, #T_1e524_row7_col20, #T_1e524_row7_col21, #T_1e524_row7_col22, #T_1e524_row7_col23, #T_1e524_row7_col24, #T_1e524_row7_col25, #T_1e524_row8_col5, #T_1e524_row8_col6, #T_1e524_row8_col7, #T_1e524_row8_col8, #T_1e524_row8_col9, #T_1e524_row8_col10, #T_1e524_row8_col11, #T_1e524_row8_col12, #T_1e524_row8_col13, #T_1e524_row8_col14, #T_1e524_row8_col15, #T_1e524_row8_col16, #T_1e524_row8_col17, #T_1e524_row8_col18, #T_1e524_row8_col19, #T_1e524_row8_col20, #T_1e524_row8_col21, #T_1e524_row8_col22, #T_1e524_row8_col23, #T_1e524_row8_col24, #T_1e524_row8_col25, #T_1e524_row9_col6, #T_1e524_row9_col7, #T_1e524_row9_col8, #T_1e524_row9_col9, #T_1e524_row9_col10, #T_1e524_row9_c ...

# %%
conf_example = pd.read_csv('../kaggle-whats-cooking/data/conf.csv',sep=';').set_index('index')

# %%
conf_example
# Out:
#               greek  southern_us  filipino  indian  jamaican  spanish  \
# index
# greek          1508           74         0      52         0       34
# southern_us      28         5418        27      99        36       64
# filipino          0           38       655      12         1        1
# indian            1           38        16    4482        16       18
# jamaican          7           63        10      67       739       10
# spanish          34           23        44      22         0      730
# italian         112          310         0      60         9       79
# mexican           1          226        27      41        21       89
# chinese           0           56        88      30         4        4
# british          24          359        22      84        15        6
# thai              4            6        40     109         4        0
# vietnamese        0           23         2      51         0       21
# cajun_creole      9          492        10       0         0       19
# brazilian         0           91        12      21         5       19
# french           52          261         0      46        10       76
# japanese          5           39        23     212         0        0
# irish             0           95         2       7         3        6
# korean            0           28         6       0         0        0
# moroccan         47           12         0      62         0       37
# russian          40           56        27      75         0       20
#
#               italian  mexican  chinese  british  thai  vietnamese  \
# index
# greek             208       13        0        0     0           0
# southern_us       257      215        6       36    20           0
# filipino           43       14       37        2    43          48
# indian             16      100        3        3     3           0
# jamaican            2       32       55        0     0           0
# spanish           226       78        2       36     0           0
# italian         12326      121        0       44     0           0
# mexican           189    10101       11        8     4           2
# chinese           112       25     4365       19    65          54
# british           102        6        3      353     4           2
# thai               12       15      213        1  2350         197
# vietnamese         15       22      117        0   383         664
# cajun_creole      134       62        0        5     0           0
# brazilian          56       91        5       15     3           0
# french            751       30       46       32     0           1
# japanese           40        8      204        0    30          17
# irish              76       21        1       34     0           0
# korean             15       34      177        0    15          18
# moroccan           59       64        4        1     8           2
# russian           144       10        1       30     0           0
#
#               cajun_creole  brazilian  french  japanese  irish  korean  \
# index
# greek                    7          0      62         7      0       0
# southern_us            180         11     245        22     26       1
# filipino                24          3      16        32      0      38
# indian                   2          2      47         5      5       0
# jamaican                25          3       8         4      4       0
# spanish                 42          8     138         0      0       0
# italian                 91          0     663         3     27       1
# mexican                  8          1      69         3     11      13
# chinese                  1          2      27       147      1     136
# british                 25          7     276        16     99       0
# thai                    14         19      13        34      0      26
# vietnamese               0          5      19         1      6      11
# cajun_creole          2019          2     123         0      0       0
# brazilian                3        331      11         2      6       0
# french                  43          0    3267        44    109       0
# japanese                 0          3      58      1429      1      63
# irish                   29          0     222         2    547       0
# korean                   0          0       0        85     10     853
# moroccan                 0          3      30         2      0       0
# russian                  9          3     176        11     50       6
#
#               moroccan  russian
# index
# greek               24        1
# southern_us         24        2
# filipino             0        4
# indian             121        0
# jamaican            20        0
# spanish             29        0
# italian             57        8
# mexican              5        7
# chinese              1        2
# british              0       30
# thai                 0        0
# vietnamese           0        0
# cajun_creole         0       18
# brazilian            0        1
# french              12        7
# japanese             0        0
# irish               18        0
# korean               0        0
# moroccan           978        2
# russian             14      118

# %%
pretty_pandas(
    conf_example,
    index='show',
    font_size=11,
    header_size=12,
    default_fill_color='#F9F9FF',
    default_text_color='#555',
    #default_border='1px solid #CCC',
    configs=make_palette(50,99,palette=['white','yellow','yellow','red'],number='pct')
)
# Out:
# <style type="text/css">
# #T_4dbbe_ tr {
#   background-color: white !important;
# }
# #T_4dbbe_row0_col0, #T_4dbbe_row10_col10, #T_4dbbe_row12_col12 {
#   background-color: #FCEFA6;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row0_col1, #T_4dbbe_row5_col7, #T_4dbbe_row6_col5, #T_4dbbe_row7_col14, #T_4dbbe_row9_col3, #T_4dbbe_row14_col5, #T_4dbbe_row16_col6, #T_4dbbe_row19_col3 {
#   background-color: #FFFEFB;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row0_col2, #T_4dbbe_row0_col4, #T_4dbbe_row0_col8, #T_4dbbe_row0_col9, #T_4dbbe_row0_col10, #T_4dbbe_row0_col11, #T_4dbbe_row0_col12, #T_4dbbe_row0_col13, #T_4dbbe_row0_col15, #T_4dbbe_row0_col16, #T_4dbbe_row0_col17, #T_4dbbe_row0_col19, #T_4dbbe_row1_col8, #T_4dbbe_row1_col11, #T_4dbbe_row1_col13, #T_4dbbe_row1_col17, #T_4dbbe_row1_col19, #T_4dbbe_row2_col0, #T_4dbbe_row2_col4, #T_4dbbe_row2_col5, #T_4dbbe_row2_col9, #T_4dbbe_row2_col13, #T_4dbbe_row2_col16, #T_4dbbe_row2_col18, #T_4dbbe_row2_col19, #T_4dbbe_row3_col0, #T_4dbbe_row3_col8, #T_4dbbe_row3_col9, #T_4dbbe_row3_col10, #T_4dbbe_row3_col11, #T_4dbbe_row3_col12, #T_4dbbe_row3_col13, #T_4dbbe_row3_col15, #T_4dbbe_row3_col16, #T_4dbbe_row3_col17, #T_4dbbe_row3_col19, #T_4dbbe_row4_col0, #T_4dbbe_row4_col2, #T_4dbb
10, #T_4dbbe_row14_col11, #T_4dbbe_row14_col13, #T_4dbbe_row14_col17, #T_4dbbe_row14_col19, #T_4dbbe_row15_col0, #T_4dbbe_row15_col4, #T_4dbbe_row15_col5, #T_4dbbe_row15_col7, #T_4dbbe_row15_col9, #T_4dbbe_row15_col12, #T_4dbbe_row15_col13, #T_4dbbe_row15_col16, #T_4dbbe_row15_col18, #T_4dbbe_row15_col19, #T_4dbbe_row16_col0, #T_4dbbe_row16_col2, #T_4dbbe_row16_col3, #T_4dbbe_row16_col4, #T_4dbbe_row16_col5, #T_4dbbe_row16_col8, #T_4dbbe_row16_col10, #T_4dbbe_row16_col11, #T_4dbbe_row16_col13, #T_4dbbe_row16_col15, #T_4dbbe_row16_col17, #T_4dbbe_row16_col19, #T_4dbbe_row17_col0, #T_4dbbe_row17_col2, #T_4dbbe_row17_col3, #T_4dbbe_row17_col4, #T_4dbbe_row17_col5, #T_4dbbe_row17_col9, #T_4dbbe_row17_col12, #T_4dbbe_row17_col13, #T_4dbbe_row17_col14, #T_4dbbe_row17_col16, #T_4dbbe_row17_col18, #T_4dbbe_row17_col19, #T_4dbbe_row18_col2, #T_4dbbe_row18_col4, #T_4dbbe_row18_col8, #T_4dbbe_row18_col9, #T_4dbbe_row18_col10, #T_4dbbe_row18_col11, #T_4dbbe_row18_col12, #T_4dbbe_row18_col13, #T_4dbbe_row18_col15, #T_4dbbe_row18_col16, #T_4dbbe ...
#   background-color: #FFFFFF;
#   color: #000;
#   color: #;
# }
# #T_4dbbe_row0_col3, #T_4dbbe_row1_col4, #T_4dbbe_row1_col9, #T_4dbbe_row2_col1, #T_4dbbe_row2_col6, #T_4dbbe_row2_col8, #T_4dbbe_row2_col10, #T_4dbbe_row2_col11, #T_4dbbe_row2_col17, #T_4dbbe_row3_col1, #T_4dbbe_row3_col14, #T_4dbbe_row5_col2, #T_4dbbe_row5_col9, #T_4dbbe_row5_col12, #T_4dbbe_row6_col9, #T_4dbbe_row7_col3, #T_4dbbe_row10_col2, #T_4dbbe_row11_col3, #T_4dbbe_row14_col0, #T_4dbbe_row14_col3, #T_4dbbe_row14_col8, #T_4dbbe_row14_col12, #T_4dbbe_row14_col15, #T_4dbbe_row15_col1, #T_4dbbe_row15_col6, #T_4dbbe_row18_col0, #T_4dbbe_row18_col5, #T_4dbbe_row19_col0, #T_4dbbe_row19_col16 {
#   background-color: #FFFFFD;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row0_col5, #T_4dbbe_row0_col18, #T_4dbbe_row1_col0, #T_4dbbe_row1_col2, #T_4dbbe_row1_col10, #T_4dbbe_row1_col15, #T_4dbbe_row1_col16, #T_4dbbe_row1_col18, #T_4dbbe_row2_col12, #T_4dbbe_row2_col15, #T_4dbbe_row4_col7, #T_4dbbe_row4_col12, #T_4dbbe_row4_col18, #T_4dbbe_row5_col0, #T_4dbbe_row5_col1, #T_4dbbe_row5_col3, #T_4dbbe_row5_col18, #T_4dbbe_row6_col16, #T_4dbbe_row7_col2, #T_4dbbe_row7_col4, #T_4dbbe_row8_col3, #T_4dbbe_row8_col7, #T_4dbbe_row8_col14, #T_4dbbe_row9_col0, #T_4dbbe_row9_col2, #T_4dbbe_row9_col12, #T_4dbbe_row9_col19, #T_4dbbe_row10_col15, #T_4dbbe_row10_col17, #T_4dbbe_row11_col1, #T_4dbbe_row11_col5, #T_4dbbe_row11_col7, #T_4dbbe_row13_col3, #T_4dbbe_row14_col7, #T_4dbbe_row14_col9, #T_4dbbe_row15_col2, #T_4dbbe_row15_col10, #T_4dbbe_row16_col7, #T_4dbbe_row16_col9, #T_4dbbe_row16_col12, #T_4dbbe_row17_col1, #T_4dbbe_row17_col7, #T_4dbbe_row18_col14, #T_4dbbe_row19_col2, #T_4dbbe_row19_col5, #T_4dbbe_row19_col9 {
#   background-color: #FFFFFE;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row0_col6, #T_4dbbe_row1_col7, #T_4dbbe_row10_col8, #T_4dbbe_row15_col3, #T_4dbbe_row15_col8 {
#   background-color: #FFFDF3;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row0_col7, #T_4dbbe_row2_col3, #T_4dbbe_row2_col7, #T_4dbbe_row2_col14, #T_4dbbe_row3_col2, #T_4dbbe_row3_col4, #T_4dbbe_row3_col5, #T_4dbbe_row3_col6, #T_4dbbe_row7_col17, #T_4dbbe_row8_col9, #T_4dbbe_row9_col4, #T_4dbbe_row9_col15, #T_4dbbe_row10_col6, #T_4dbbe_row10_col7, #T_4dbbe_row10_col12, #T_4dbbe_row10_col13, #T_4dbbe_row10_col14, #T_4dbbe_row11_col6, #T_4dbbe_row11_col14, #T_4dbbe_row12_col5, #T_4dbbe_row12_col19, #T_4dbbe_row13_col2, #T_4dbbe_row13_col5, #T_4dbbe_row13_col9, #T_4dbbe_row14_col18, #T_4dbbe_row15_col11, #T_4dbbe_row16_col18, #T_4dbbe_row17_col6, #T_4dbbe_row17_col10, #T_4dbbe_row17_col11, #T_4dbbe_row18_col1, #T_4dbbe_row19_col18 {
#   background-color: #FFFFFF;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row0_col14, #T_4dbbe_row1_col5, #T_4dbbe_row4_col1, #T_4dbbe_row4_col3, #T_4dbbe_row6_col3, #T_4dbbe_row6_col18, #T_4dbbe_row8_col10, #T_4dbbe_row12_col7, #T_4dbbe_row15_col14, #T_4dbbe_row15_col17, #T_4dbbe_row18_col3, #T_4dbbe_row18_col6, #T_4dbbe_row18_col7 {
#   background-color: #FFFEFC;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row1_col1, #T_4dbbe_row3_col3, #T_4dbbe_row6_col6, #T_4dbbe_row7_col7, #T_4dbbe_row8_col8 {
#   background-color: #E77270;
#   color: #000;
#   color: #color;
# }
# #T_4dbbe_row1_col3, #T_4dbbe_row3_col7, #T_4dbbe_row6_col12, #T_4dbbe_row7_col5, #T_4dbbe_row8_col2, #T_4dbbe_row9_col16, #T_4dbbe_row13_col1, #T_4dbbe_row13_col7, #T_4dbbe_row16_col1,
